# %% [markdown]
# <!-- ID attribute for the table of contents -->
# # Capstone: Retail Analyst

# %% [markdown]
# ## Introduction
#
# In this project, I will be working as a retail analyst for an online retailer. The aim of this project is to analyze some of the key metrics related to the retail business, such as sales trends, customer behavior, product performance, customer segmentation, competitive analysis, customer experience, and inventory management. The ultimate goals of this project are to refine the product offering, increase order size, plan product assortments, forecast sales, and optimize e-commerce strategies. Through this analysis, we hope to provide valuable insights that can help the retailer make data-driven decisions to improve their business performance.

# %% [markdown]
# With the given dataset, we can perform various analyses and extract valuable insights to help improve your ecommerce store's performance. Here are some key analyses we will conduct:
#
# #### 1. Sales Performance Analysis:
#
# - Calculate total revenue, average revenue per order, and revenue by product
# - Identify top-selling products and categories based on revenue and quantity sold
# - Provide insights and recommendations based on the findings.
#
# #### 2. Pricing & Profitability Analysis:
#
# - Evaluate the impact of price changes on sales volume
# - Calculate profit margins for each product using Quantity and UnitPrice
# - Identify high-margin and low-margin products
#
# #### 3. Customer Segmentation:
#
# - Group customers by their purchase patterns, frequency, and monetary value
# - Create customer profiles to better understand their demographics and preferences
# - Develop targeted marketing strategies for each customer segment
#
# #### 4. Geographic Analysis:
#
# - Analyze sales performance by country
# - Identify high-potential markets for expansion
# - Customize marketing strategies based on regional preferences
#
# #### 5. Time-Based Analysis:
#
# - Determine peak shopping hours and days
# - Optimize promotional campaigns and staffing based on peak shopping periods
# - Analyze the impact of holidays and special events on sales
#
# #### 6. Inventory Analysis:
#
# - Analyze product stock levels and turnover rates
# - Identify slow-moving or overstocked items
# - Optimize inventory management to reduce carrying costs and stockouts
#
# #### 7. Customer Retention Analysis:
#
# - Calculate customer churn rate and average customer lifetime value
# - Identify factors contributing to customer attrition
# - Develop strategies to improve customer loyalty and retention
#
# #### 8. Market Basket Analysis:
# - Market basket analysis is a type of analysis used to understand the purchase behavior of customers. It's based on the concept that if you buy a certain group of items, you are more (or less) likely to buy another group of items.
#
# To perform these analyses, I will first clean and preprocess the dataset, addressing any missing or incorrect data. Then, I will utilize various analytical tools and techniques such as descriptive statistics, clustering, and time series analysis to uncover valuable insights and make data-driven recommendations for your e-commerce store.

# %% [markdown]
# <a id="top"></a>
#
# ## Table of Contents:
#
# [Data Dictionary](#Data-Dictionary)
#
# [Exploratory Data Analysis](#EDA)
#
# 1. [Sales Performance Analysis](#Sales-Performance-Analysis)
# 2. [Pricing & Profitability Analysis](#Pricing-Profitability-Analysis)
# 3. [Customer Segmentation](#Customer-Segmentation)
# 4. [Geographic Analysis](#Geographic-Analysis)
# 5. [Time-Based Analysis](#Time-Based-Analysis)
# 6. [Inventory Analysis](#Inventory-Analysis)
# 7. [Customer Retention Analysis](#Customer-Retention-Analysis)
# 8. [Market Basket Analysis](#MBA)
#
# [Conclusion](#EDA)

# %%
# Import necessary modules
import pandas as pd
import numpy as np
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import time
from time import time
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
from scipy import sparse
from math import ceil
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.impute import SimpleImputer
from sklearn.metrics import precision_recall_fscore_support
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
import matplotlib.ticker as ticker
import matplotlib.ticker as mtick
import os
import datetime as dt
from mlxtend.frequent_patterns import apriori, association_rules


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data Dictionary
#
#
# | Column | Information |
# | :- |  :- |
# | InvoiceNo | *Invoice Number* |
# | StockCode | *Product Stock Code* |
# | Description | *Product Description* |
# | Quantity | *Product Quantity* |
# | InvoiceDate | *Invoice Date* |
# | UnitPrice | *Product Unit Price* |
# | CustomerID | *Customer ID* |
# | Country | *Origin of order* |

# %% [markdown]
# <a id="EDA"></a>
# ## Exploration & Cleaning

# %% [markdown]
# To perform these analyses, I will first clean and preprocess the dataset, addressing any missing or incorrect data. Then, I will utilize various analytical tools and techniques such as descriptive statistics, clustering, and time series analysis to uncover valuable insights and make data-driven recommendations for your e-commerce store.

# %%
# Load the data set
data = pd.read_csv('downloads/online_retail.csv')
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])
data = data.loc[data['InvoiceDate'] <= '2011-12-01']

# %% [markdown]
# The data set had 1 full year plus 9 days, I decided to remove the extra days to make the data more cohesive.

# %%
# Let's have a look at the data
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# The data set had 1 full year plus 9 days, I decided to remove the extra days to make the data more cohesive.

# %%
# print the shape of the dataset
print('Shape of data Set: ', data.shape)
# Out:
# Shape of data Set:  (516384, 8)

# %%
# Another way to look at the shape
print("Data Set")
print(f"Rows: {data.shape[0]}")
print(f"Columns: {data.shape[1]}")
print(f"Missing data: {data.isna().sum().sum()}")
# Out:
# Data Set
# Rows: 516384
# Columns: 8
# Missing data: 128655

# %%
# Missing data detail
print(f"Missing data: {data.isna().sum()}")
# Out:
# Missing data: InvoiceNo           0
# StockCode           0
# Description      1439
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     127216
# Country             0
# dtype: int64

# %%
# Looking at the info in our data set
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 516384 entries, 0 to 516383
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    516384 non-null  object
#  1   StockCode    516384 non-null  object
#  2   Description  514945 non-null  object
#  3   Quantity     516384 non-null  int64
#  4   InvoiceDate  516384 non-null  datetime64[ns]
#  5   UnitPrice    516384 non-null  float64
#  6   CustomerID   389168 non-null  float64
#  7   Country      516384 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 35.5+ MB

# %%
# replace missing customer IDs with dummy ID
# I decided to do this as I did not want to lose 135,000 rows of data as the mix of sales might be affected. 
data['CustomerID'].fillna(9999900000, inplace=True)

# %%
# drop all rows that contain missing values
# We have some missing values in the Description column, it's only affecting about 500 rows of data, so i decided to drop.
data.dropna(inplace=True)

# %%
# Looking at the info in our data set
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 514945 entries, 0 to 516383
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    514945 non-null  object
#  1   StockCode    514945 non-null  object
#  2   Description  514945 non-null  object
#  3   Quantity     514945 non-null  int64
#  4   InvoiceDate  514945 non-null  datetime64[ns]
#  5   UnitPrice    514945 non-null  float64
#  6   CustomerID   514945 non-null  float64
#  7   Country      514945 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 35.4+ MB

# %%
# Lerts look at the distribution of the the numarical columns
data.describe()
# Out:
#             Quantity      UnitPrice    CustomerID
# count  514945.000000  514945.000000  5.149450e+05
# mean        9.639181       4.592507  2.442520e+09
# std       156.012201      94.419034  4.296390e+09
# min    -74215.000000  -11062.060000  1.234600e+04
# 25%         1.000000       1.250000  1.435700e+04
# 50%         3.000000       2.080000  1.622200e+04
# 75%        10.000000       4.130000  1.822600e+04
# max     74215.000000   38970.000000  9.999900e+09

# %% [markdown]
# Looks like we have some negative values in `Quantity` and `UnitPrice`, let's go ahead and drop all these

# %%
# drop rows with negative values in Quantity and UnitPrice columns
data = data.drop(data[data['Quantity'] < 0].index)
data = data.drop(data[data['UnitPrice'] < 1].index)
# We're going to remove any item priced less than $1 ($0-$.99 removed)

# %%
# let's have a look at the data
data.head()
# Out:
#     InvoiceNo StockCode                          Description  Quantity  \
# 0      536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365     71053                  WHITE METAL LANTERN         6
# 2      536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ..        ...       ...                                  ...       ...
# 109    536381     82567            AIRLINE LOUNGE,METAL SIGN         2
# 110    536381     21672   WHITE SPOT RED CERAMIC DRAWER KNOB         6
# 111    536381     22774    RED DRAWER KNOB ACRYLIC EDWARDIAN        24
# 112    536381     22771  CLEAR DRAWER KNOB ACRYLIC EDWARDIAN        24
# 113    536381     71270                      PHOTO CLIP LINE         1
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0   2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1   2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2   2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3   2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4   2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ..                  ...        ...         ...             ...
# 109 2010-12-01 09:41:00       2.10     15311.0  United Kingdom
# 110 2010-12-01 09:41:00       1.25     15311.0  United Kingdom
# 111 2010-12-01 09:41:00       1.25     15311.0  United Kingdom
# 112 2010-12-01 09:41:00       1.25     15311.0  United Kingdom
# 113 2010-12-01 09:41:00       1.25     15311.0  United Kingdom
#
# [100 rows x 8 columns]

# %%
# Filter out rows containing 'postage' or 'dotcom postage' in the description
data = data[~data['Description'].str.contains('POSTAGE|DOTCOM POSTAGE', case=False)]

# %% [markdown]
# <a id="Sales-Performance-Analysis"></a>
# ## 1. Sales Performance Analysis

# %% [markdown]
# We will calculate the total revenue using some feature engineering by multiplying the `Quantity` and `UnitPrice` columns, and then add a new `Revenue` column to the DataFrame:

# %%
data['Revenue'] = data['Quantity'] * data['UnitPrice']

# %% [markdown]
# Calculate total revenue, average revenue per order, and revenue by product:

# %%
# Total revenue
total_revenue = data['Revenue'].sum()
print(f"Total Revenue: {total_revenue}")

# Average revenue per order
average_revenue_per_order = data.groupby('InvoiceNo')['Revenue'].sum().mean()
print(f"Average Revenue per Order: {average_revenue_per_order}")

# Revenue by product
product_revenue = data.groupby('Description')['Revenue'].sum().sort_values(ascending=False)
print("Revenue by Product:\n", product_revenue)
# Out:
# Total Revenue: 8712156.209999999
# Average Revenue per Order: 466.6143329227144
# Revenue by Product:
#  Description
# REGENCY CAKESTAND 3 TIER              168477.87
# WHITE HANGING HEART T-LIGHT HOLDER    104085.75
# PARTY BUNTING                          98585.85
# JUMBO BAG RED RETROSPOT                92113.15
# MEDIUM CERAMIC TOP STORAGE JAR         81448.21
#                                         ...
# LETTER "B" BLING KEY RING                  1.25
# WIRE FLOWER T-LIGHT HOLDER                 1.25
# DUSTY PINK CHRISTMAS TREE 30CM             1.25
# S/4 ICON COASTER,ELVIS LIVES               1.25
# DECORATION SITTING BUNNY                   1.21
# Name: Revenue, Length: 3633, dtype: float64

# %% [markdown]
# #### I wanted a better way to look at this data, and possibly see how long the product tail is. The below code shows this well.

# %%
# Total revenue
total_revenue = data['Revenue'].sum()
print(f"Total Revenue: ${total_revenue:,.2f}")

# Average revenue per order
average_revenue_per_order = data.groupby('InvoiceNo')['Revenue'].sum().mean()
print(f"Average Revenue per Order: ${average_revenue_per_order:.2f}")

# Revenue by product
product_revenue = data.groupby('Description')['Revenue'].sum().sort_values(ascending=False)
print("Revenue by Product:")
print("| Description                           | Revenue     |")
print("|---------------------------------------|-------------|")
for description, revenue in product_revenue.items():
    print(f"| {description:<38} | ${revenue:,.2f} |")
# Out:
# Total Revenue: $8,712,156.21
# Average Revenue per Order: $466.61
# Revenue by Product:
# | Description                           | Revenue     |
# |---------------------------------------|-------------|
# | REGENCY CAKESTAND 3 TIER               | $168,477.87 |
# | WHITE HANGING HEART T-LIGHT HOLDER     | $104,085.75 |
# | PARTY BUNTING                          | $98,585.85 |
# | JUMBO BAG RED RETROSPOT                | $92,113.15 |
# | MEDIUM CERAMIC TOP STORAGE JAR         | $81,448.21 |
# | Manual                                 | $76,406.20 |
# | PAPER CHAIN KIT 50'S CHRISTMAS         | $58,081.58 |
# | RABBIT NIGHT LIGHT                     | $57,321.97 |
# | ASSORTED COLOUR BIRD ORNAMENT          | $56,932.19 |
# | CHILLI LIGHTS                          | $51,478.02 |
# | SPOTTY BUNTING                         | $41,783.27 |
# | JUMBO BAG PINK POLKADOT                | $41,509.92 |
# | PICNIC BASKET WICKER 60 PIECES         | $39,619.50 |
# | SET OF 3 CAKE TINS PANTRY DESIGN       | $37,070.24 |
# | DOORMAT KEEP CALM AND COME IN          | $36,591.92 |
# | JAM MAKING SET WITH JARS               | $35,860.85 |
# | BLACK RECORD COVER FRAME               | $35,069.70 |
# | LUNCH BAG RED RETROSPOT                | $34,975.66 |
# | WOOD BLACK BOARD ANT WHITE FINISH      | $33,687.64 |
# | JUMBO BAG STRAWBERRY                   | $32,224.96 |
# | HEART OF WICKER SMALL                  | $31,806.72 |
# | PAPER CHAIN KIT VINTAGE CHRISTMAS      | $30,109.78 |
# | JUMBO STORAGE BAG SUKI                 | $29,925.68 |
# | JUMBO BAG APPLES                       | $29,903.15 |
# | HEART OF WICKER LARGE                  | $29,798.31 |
# | SET OF 3 REGENCY CAKE TINS             | $29,498.66 |
# | VICTORIAN GLASS HANGING T-LIGHT        | $29,402.51 |
# | CHOCOLATE HOT WATER BOTTLE             | $29,395.94 |
# | HOT WATER BOTTLE TEA AND SYMPATHY      | $29,267.79 |
# | ROSES REGENCY TEACUP AND SAUCER        | $28,047.54 |
# | JUMBO SHOPPER VINTAGE RED PAISLEY      | $27,551.79 |
# | JUMBO  BAG BAROQUE BLACK WHITE         | $27,456.25 |
# | DOORMAT RED RETROSPOT                  | $27,426.48 |
# | ALARM CLOCK BAKELIKE RED               | $26,886.72 |
# | JUMBO BAG ALPHABET                     | $26,627.39 |
# | GIN + TONIC DIET METAL SIGN            | $25,836.57 |
# | NATURAL SLATE HEART CHALKBOARD         | $25,476.60 |
# | ALARM CLOCK BAKELIKE GREEN             | $25,361.30 |
# | RED  HARMONICA IN BOX                  | $25,106.60 |
# | DOORMAT UNION FLAG                     | $24,993.11 |
# | SPACEBOY LUNCH BOX                     | $24,952.15 |
# | HOT WATER BOTTLE KEEP CALM             | $24,867.87 |
# | RECIPE BOX PANTRY YELLOW DESIGN        | $24,577.71 |
# | REGENCY TEAPOT ROSES                   | $24,442.37 |
# | VINTAGE UNION JACK BUNTING             | $24,262.70 |
# | SET OF 6 SPICE TINS PANTRY DESIGN      | $23,980.55 |
# | DOORMAT NEW ENGLAND                    | $23,961.49 |
# | JAM MAKING SET PRINTED                 | $23,929.42 |
# | DOORMAT FAIRY CAKE                     | $23,781.56 |
# | PLEASE ONE PERSON METAL SIGN           | $23,776.46 |
# | ROTATING SILVER ANGELS T-LIGHT HLDR    | $23,763.05 |
# | ROUND SNACK BOXES SET OF4 WOODLAND     | $23,629.07 |
# | EDWARDIAN PARASOL NATURAL              | $23,247.93 |
# | JUMBO BAG VINTAGE DOILY                | $23,170.78 |
# | SET OF TEA COFFEE SUGAR TINS PANTRY    | $23,145.99 |
# | RED TOADSTOOL LED NIGHT LIGHT          | $22,950.13 |
# | BAKING SET 9 PIECE RETROSPOT           | $22,877.71 |
# | JUMBO BAG PINK VINTAGE PAISLEY         | $22,790.69 |
# | WOODEN PICTURE FRAME WHITE FINISH      | $22,621.32 |
# | RED HANGING HEART T-LIGHT HOLDER       | $22,463.45 |
# | PAPER BUNTING RETROSPOT                | $22,447.63 |
# | VINTAGE UNION JACK MEMOBOARD           | $22,411.79 |
# | SCOTTIE DOG HOT WATER BOTTLE           | $22,369.93 |
# | CREAM HEART CARD HOLDER                | $22,026.84 |
# | JUMBO BAG OWLS                         | $21,975.60 |
# | DOORMAT HEARTS                         | $21,850.81 |
# | GREEN REGENCY TEACUP AND SAUCER        | $21,810.67 |
# | RETROSPOT TEA SET CERAMIC 11 PC        | $21,754.51 |
# | LUNCH BAG  BLACK SKULL.                | $21,732.37 |
# | JUMBO BAG WOODLAND ANIMALS             | $21,649.04 |
# | JUMBO BAG 50'S CHRISTMAS               | $21,570.80 |
# | LUNCH BAG CARS BLUE                    | $21,485.67 |
# | DOLLY GIRL LUNCH BOX                   | $21,239.13 |
# | CREAM SWEETHEART MINI CHEST            | $21,168.21 |
# | DOORMAT FANCY FONT HOME SWEET HOME     | $21,157.55 |
# | WOODEN FRAME ANTIQUE WHITE             | $21,007.75 |
# | JUMBO BAG VINTAGE LEAF                 | $20,840.36 |
# | LUNCH BOX I LOVE LONDON                | $20,589.71 |
# | LUNCH BAG APPLE DESIGN                 | $20,388.25 |
# | RED WOOLLY HOTTIE WHITE HEART.         | $20,348.88 |
# | RED RETROSPOT CAKE STAND               | $20,228.85 |
# | CHARLOTTE BAG SUKI DESIGN              | $19,959.03 |
# | ALARM CLOCK BAKELIKE PINK              | $19,866.14 |
# | PICNIC BASKET WICKER LARGE             | $19,322.16 |
# | COOK WITH WINE METAL SIGN              | $19,072.59 |
# | ROUND SNACK BOXES SET OF 4 FRUITS      | $18,811.77 |
# | WHITE SKULL HOT WATER BOTTLE           | $18,527.54 |
# | ANTIQUE SILVER T-LIGHT GLASS           | $18,440.88 |
# | HOMEMADE JAM SCENTED CANDLES           | $18,385.13 |
# | LUNCH BAG SUKI DESIGN                  | $18,355.88 |
# | GUMBALL COAT RACK                      | $18,169.81 |
# | LUNCH BAG WOODLAND                     | $17,935.50 |
# | LUNCH BAG SPACEBOY DESIGN              | $17,831.61 |
# | JUMBO BAG DOILEY PATTERNS              | $17,272.85 |
# | SET/5 RED RETROSPOT LID GLASS BOWLS    | $17,175.31 |
# | LUNCH BAG PINK POLKADOT                | $17,171.90 |
# | COLOUR GLASS. STAR T-LIGHT HOLDER      | $17,073.65 |
# | RETROSPOT HEART HOT WATER BOTTLE       | $16,846.14 |
# | PINK REGENCY TEACUP AND SAUCER         | $16,687.50 |
# | JUMBO BAG SCANDINAVIAN BLUE PAISLEY    | $16,652.87 |
# | HOME BUILDING BLOCK WORD               | $16,648.02 |
# | 6 RIBBONS RUSTIC CHARM                 | $16,571.62 |
# | EDWARDIAN PARASOL BLACK                | $16,405.49 |
# | JUMBO BAG SPACEBOY DESIGN              | $16,393.00 |
# | HOT WATER BOTTLE I AM SO POORLY        | $16,326.63 |
# | CHILDRENS CUTLERY POLKADOT PINK        | $16,280.69 |
# | HOT BATHS METAL SIGN                   | $16,234.22 |
# | HANGING HEART JAR T-LIGHT HOLDER       | $16,214.69 |
# | SET/4 WHITE RETRO STORAGE CUBES        | $16,185.16 |
# | HAND WARMER OWL DESIGN                 | $16,151.82 |
# | SET OF 4 PANTRY JELLY MOULDS           | $15,868.60 |
# | IVORY KITCHEN SCALES                   | $15,837.82 |
# | FAIRY CAKE FLANNEL ASSORTED COLOUR     | $15,490.71 |
# | RECYCLING BAG RETROSPOT                | $15,248.80 |
# | PAPER CHAIN KIT EMPIRE                 | $15,090.52 |
# | GARDENERS KNEELING PAD KEEP CALM       | $14,706.13 |
# | KNITTED UNION FLAG HOT WATER BOTTLE    | $14,672.52 |
# | WOOD 2 DRAWER CABINET WHITE FINISH     | $14,488.13 |
# | HAND OVER THE CHOCOLATE   SIGN         | $14,190.78 |
# | VINTAGE CHRISTMAS BUNTING              | $14,079.86 |
# | BREAD BIN DINER STYLE IVORY            | $13,999.15 |
# | DOORMAT ENGLISH ROSE                   | $13,955.56 |
# | JUMBO BAG PEARS                        | $13,921.00 |
# | STRAWBERRY CERAMIC TRINKET BOX         | $13,892.64 |
# | MEMO BOARD RETROSPOT  DESIGN           | $13,869.93 |
# | AMAZON FEE                             | $13,761.09 |
# | RED KITCHEN SCALES                     | $13,652.62 |
# | SET 7 BABUSHKA NESTING BOXES           | $13,579.82 |
# | PAPER CHAIN KIT RETROSPOT              | $13,570.27 |
# | BOX OF VINTAGE ALPHABET BLOCKS         | $13,470.62 |
# | JUMBO STORAGE BAG SKULLS               | $13,412.87 |
# | 3 HOOK PHOTO SHELF ANTIQUE WHITE       | $13,406.48 |
# | PINK BLUE FELT CRAFT TRINKET BOX       | $13,379.94 |
# | DOORMAT SPOTTY HOME SWEET HOME         | $13,281.38 |
# | PLASTERS IN TIN SPACEBOY               | $13,205.63 |
# | HAND WARMER SCOTTY DOG DESIGN          | $13,182.52 |
# | LUNCH BAG ALPHABET DESIGN              | $13,144.80 |
# | PLASTERS IN TIN WOODLAND ANIMALS       | $13,013.32 |
# | DOUGHNUT LIP GLOSS                     | $13,001.09 |
# | TEA TIME PARTY BUNTING                 | $12,936.32 |
# | CLOTHES PEGS RETROSPOT PACK 24         | $12,879.70 |
# | ENAMEL FLOWER JUG CREAM                | $12,671.06 |
# | WOODEN UNION JACK BUNTING              | $12,639.02 |
# | SET OF 10 LED DOLLY LIGHTS             | $12,604.67 |
# | LOVE HOT WATER BOTTLE                  | $12,580.90 |
# | HAND WARMER BIRD DESIGN                | $12,532.81 |
# | FELTCRAFT 6 FLOWER FRIENDS             | $12,373.88 |
# | FELTCRAFT CUSHION OWL                  | $12,350.14 |
# | LOVE BUILDING BLOCK WORD               | $12,335.37 |
# | JUMBO BAG VINTAGE CHRISTMAS            | $12,265.40 |
# | RED RETROSPOT MINI CASES               | $12,263.17 |
# | GREY HEART HOT WATER BOTTLE            | $12,205.87 |
# | WOODEN ROUNDERS GARDEN SET             | $12,161.55 |
# | CHRISTMAS LIGHTS 10 REINDEER           | $12,152.99 |
# | CHILDRENS CUTLERY RETROSPOT RED        | $12,139.30 |
# | REGENCY SUGAR BOWL GREEN               | $12,135.03 |
# | GROW A FLYTRAP OR SUNFLOWER IN TIN     | $12,118.71 |
# | PINK HAPPY BIRTHDAY BUNTING            | $12,108.86 |
# | DOORMAT WELCOME PUPPIES                | $12,106.72 |
# | ENAMEL BREAD BIN CREAM                 | $12,005.65 |
# | WOOD S/3 CABINET ANT WHITE FINISH      | $11,937.68 |
# | CHILDRENS CUTLERY POLKADOT BLUE        | $11,839.84 |
# | PICNIC BASKET WICKER SMALL             | $11,807.12 |
# | FELTCRAFT DOLL MOLLY                   | $11,804.60 |
# | SET 6 SCHOOL MILK BOTTLES IN CRATE     | $11,762.02 |
# | PAPER BUNTING WHITE LACE               | $11,757.53 |
# | IVORY DINER WALL CLOCK                 | $11,716.89 |
# | SET/3 RED GINGHAM ROSE STORAGE BOX     | $11,711.67 |
# | ASSORTED COLOUR MINI CASES             | $11,622.54 |
# | BLACK HEART CARD HOLDER                | $11,609.81 |
# | 3 HEARTS HANGING DECORATION RUSTIC     | $11,564.04 |
# | RED RETROSPOT PICNIC BAG               | $11,536.27 |
# | DOORMAT WELCOME TO OUR HOME            | $11,348.79 |
# | RED DINER WALL CLOCK                   | $11,336.06 |
# | FELTCRAFT CUSHION RABBIT               | $11,227.47 |
# | SET 3 RETROSPOT TEA,COFFEE,SUGAR       | $11,158.95 |
# | CLASSIC METAL BIRDCAGE PLANT HOLDER    | $11,134.81 |
# | RECORD FRAME 7" SINGLE SIZE            | $11,134.02 |
# | Adjust bad debt                        | $11,062.06 |
# | RED RETROSPOT ROUND CAKE TINS          | $11,019.25 |
# | JUMBO BAG TOYS                         | $11,010.49 |
# | GARDENERS KNEELING PAD CUP OF TEA      | $10,997.12 |
# | ALARM CLOCK BAKELIKE IVORY             | $10,979.59 |
# | LUNCH BAG DOLLY GIRL DESIGN            | $10,964.33 |
# | WOODEN CROQUET GARDEN SET              | $10,901.12 |
# | RED RETROSPOT UMBRELLA                 | $10,886.33 |
# | REGENCY TEA PLATE ROSES                | $10,859.67 |
# | FAWN BLUE HOT WATER BOTTLE             | $10,696.95 |
# | LUNCH BAG DOILEY PATTERN               | $10,510.44 |
# | RED RETROSPOT CHARLOTTE BAG            | $10,498.03 |
# | BLUE HAPPY BIRTHDAY BUNTING            | $10,459.27 |
# | SOLDIERS EGG CUP                       | $10,416.69 |
# | 15CM CHRISTMAS GLASS BALL 20 LIGHTS    | $10,325.80 |
# | BREAD BIN DINER STYLE RED              | $10,227.85 |
# | JUMBO BAG PAISLEY PARK                 | $10,219.26 |
# | DOORMAT BLACK FLOCK                    | $10,212.77 |
# | NO SINGING METAL SIGN                  | $10,195.86 |
# | BAKING SET SPACEBOY DESIGN             | $10,173.80 |
# | REVOLVER WOODEN RULER                  | $10,159.67 |
# | FELTCRAFT CUSHION BUTTERFLY            | $10,133.33 |
# | SET OF 6 RIBBONS VINTAGE CHRISTMAS     | $10,103.87 |
# | LUNCH BAG VINTAGE DOILY                | $10,052.98 |
# | VINTAGE HEADS AND TAILS CARD GAME      | $10,025.41 |
# | LONDON BUS COFFEE MUG                  | $9,998.22 |
# | LUNCH BAG VINTAGE LEAF DESIGN          | $9,932.23 |
# | FAMILY ALBUM WHITE PICTURE FRAME       | $9,839.31 |
# | RED SPOTTY BISCUIT TIN                 | $9,836.41 |
# | REGENCY TEA PLATE GREEN                | $9,751.73 |
# | TRADITIONAL WOODEN SKIPPING ROPE       | $9,742.96 |
# | DOORMAT HOME SWEET HOME BLUE           | $9,740.30 |
# | SWEETHEART CAKESTAND 3 TIER            | $9,697.25 |
# | BLUE HARMONICA IN BOX                  | $9,690.40 |
# | EDWARDIAN PARASOL RED                  | $9,689.69 |
# | PLASTERS IN TIN CIRCUS PARADE          | $9,685.70 |
# | PHOTO FRAME CORNICE                    | $9,681.56 |
# | ICE CREAM SUNDAE LIP GLOSS             | $9,646.08 |
# | DELUXE SEWING KIT                      | $9,637.77 |
# | STRAWBERRY LUNCH BOX WITH CUTLERY      | $9,599.92 |
# | ANTIQUE SILVER TEA GLASS ENGRAVED      | $9,583.24 |
# | 3 TIER CAKE TIN RED AND CREAM          | $9,573.68 |
# | PLASTERS IN TIN STRONGMAN              | $9,561.44 |
# | POPCORN HOLDER                         | $9,527.57 |
# | PANTRY ROLLING PIN                     | $9,501.51 |
# | TRADITIONAL KNITTING NANCY             | $9,454.87 |
# | REGENCY MILK JUG PINK                  | $9,440.09 |
# | VINTAGE CREAM DOG FOOD CONTAINER       | $9,425.54 |
# | T-LIGHT GLASS FLUTED ANTIQUE           | $9,387.34 |
# | NATURAL SLATE CHALKBOARD LARGE         | $9,330.64 |
# | SMALL GLASS HEART TRINKET POT          | $9,316.32 |
# | WOODEN SCHOOL COLOURING SET            | $9,261.00 |
# | SET OF 6 SOLDIER SKITTLES              | $9,118.55 |
# | HAND WARMER UNION JACK                 | $9,112.74 |
# | RED RETROSPOT PEG BAG                  | $9,106.28 |
# | LADIES & GENTLEMEN METAL SIGN          | $9,074.01 |
# | SET OF 4 KNICK KNACK TINS DOILY        | $9,060.97 |
# | ALARM CLOCK BAKELIKE ORANGE            | $9,047.04 |
# | SET OF 3 NOTEBOOKS IN PARCEL           | $9,043.94 |
# | SET OF 20 KIDS COOKIE CUTTERS          | $9,021.95 |
# | CHRISTMAS CRAFT LITTLE FRIENDS         | $8,996.01 |
# | PINK CREAM FELT CRAFT TRINKET BOX      | $8,882.33 |
# | DOORMAT MULTICOLOUR STRIPE             | $8,875.45 |
# | GINGERBREAD MAN COOKIE CUTTER          | $8,844.44 |
# | SET 2 PANTRY DESIGN TEA TOWELS         | $8,812.32 |
# | WOODLAND CHARLOTTE BAG                 | $8,773.98 |
# | FELTCRAFT PRINCESS CHARLOTTE DOLL      | $8,768.76 |
# | BOX OF 6 MINI 50'S CRACKERS            | $8,746.75 |
# | ZINC FOLKART SLEIGH BELLS              | $8,714.71 |
# | WOODEN ADVENT CALENDAR RED             | $8,714.24 |
# | LARGE WHITE HEART OF WICKER            | $8,692.91 |
# | POTTERING IN THE SHED METAL SIGN       | $8,656.40 |
# | TRAVEL SEWING KIT                      | $8,620.32 |
# | CLEAR DRAWER KNOB ACRYLIC EDWARDIAN    | $8,596.19 |
# | FELTCRAFT BUTTERFLY HEARTS             | $8,579.09 |
# | BOX OF 6 MINI VINTAGE CRACKERS         | $8,550.15 |
# | TRADITIONAL MODELLING CLAY             | $8,530.36 |
# | ICE CREAM PEN LIP GLOSS                | $8,501.20 |
# | WOODEN BOX OF DOMINOES                 | $8,439.64 |
# | AREA PATROLLED METAL SIGN              | $8,428.02 |
# | SET OF 72 RETROSPOT PAPER  DOILIES     | $8,271.45 |
# | SET OF 3 HEART COOKIE CUTTERS          | $8,240.64 |
# | HAND WARMER RED RETROSPOT              | $8,206.16 |
# | SET/2 RED RETROSPOT TEA TOWELS         | $8,186.45 |
# | SMALL WHITE HEART OF WICKER            | $8,177.94 |
# | VINTAGE RED KITCHEN CABINET            | $8,125.00 |
# |  SET 2 TEA TOWELS I LOVE LONDON        | $8,100.05 |
# | GRAND CHOCOLATECANDLE                  | $8,073.17 |
# | WHITE METAL LANTERN                    | $8,056.52 |
# | SWEETHEART RECIPE BOOK STAND           | $8,046.71 |
# | CHILDRENS CUTLERY SPACEBOY             | $8,023.65 |
# | SET 6 PAPER TABLE LANTERN HEARTS       | $7,939.99 |
# | CHICK GREY HOT WATER BOTTLE            | $7,937.88 |
# | HAND WARMER RED LOVE HEART             | $7,929.97 |
# | SET/10 RED POLKADOT PARTY CANDLES      | $7,897.60 |
# | BLUE DINER WALL CLOCK                  | $7,892.53 |
# | SET OF 3 BUTTERFLY COOKIE CUTTERS      | $7,873.24 |
# | ROSE COTTAGE KEEPSAKE BOX              | $7,822.01 |
# | FAMILY PHOTO FRAME CORNICE             | $7,794.00 |
# | WHITE WOOD GARDEN PLANT LADDER         | $7,761.62 |
# | LUNCH BOX WITH CUTLERY RETROSPOT       | $7,744.31 |
# | PAINTED METAL PEARS ASSORTED           | $7,681.99 |
# | RECIPE BOX RETROSPOT                   | $7,643.95 |
# | ALARM CLOCK BAKELIKE CHOCOLATE         | $7,626.54 |
# | DOORMAT 3 SMILEY CATS                  | $7,605.80 |
# | FELTCRAFT CHRISTMAS FAIRY              | $7,587.47 |
# | VINTAGE DOILY TRAVEL SEWING KIT        | $7,570.18 |
# |  SPACEBOY BABY GIFT SET                | $7,564.52 |
# | CREAM CUPID HEARTS COAT HANGER         | $7,520.37 |
# | METAL 4 HOOK HANGER FRENCH CHATEAU     | $7,499.19 |
# | OPEN CLOSED METAL SIGN                 | $7,488.60 |
# | DOORMAT UNION JACK GUNS AND ROSES      | $7,484.80 |
# | PLASTERS IN TIN VINTAGE PAISLEY        | $7,472.03 |
# | RED STRIPE CERAMIC DRAWER KNOB         | $7,443.51 |
# | GIRAFFE WOODEN RULER                   | $7,435.58 |
# | PACK OF 6 BIRDY GIFT TAGS              | $7,412.24 |
# | SWEETHEART CERAMIC TRINKET BOX         | $7,408.33 |
# | ZINC METAL HEART DECORATION            | $7,333.31 |
# | FELTCRAFT PRINCESS LOLA DOLL           | $7,296.99 |
# | TOY TIDY PINK POLKADOT                 | $7,278.51 |
# | CHOCOLATE THIS WAY METAL SIGN          | $7,258.85 |
# | SET OF 4 KNICK KNACK TINS DOILEY       | $7,252.94 |
# | MINT KITCHEN SCALES                    | $7,232.87 |
# | CHILDRENS APRON SPACEBOY DESIGN        | $7,193.92 |
# | SET OF 4 KNICK KNACK TINS LONDON       | $7,191.69 |
# | PIGGY BANK RETROSPOT                   | $7,121.38 |
# | METAL SIGN TAKE IT OR LEAVE IT         | $7,105.14 |
# | SILVER HANGING T-LIGHT HOLDER          | $7,079.69 |
# | BLUE STRIPE CERAMIC DRAWER KNOB        | $7,062.61 |
# | 36 DOILIES VINTAGE CHRISTMAS           | $7,061.73 |
# | CHILDRENS CUTLERY POLKADOT GREEN       | $7,053.88 |
# | CIRCUS PARADE LUNCH BOX                | $7,039.44 |
# | RETROSPOT PARTY BAG + STICKER SET      | $7,012.59 |
# | VICTORIAN SEWING BOX LARGE             | $6,998.27 |
# | RED FLORAL FELTCRAFT SHOULDER BAG      | $6,978.74 |
# | MEMO BOARD COTTAGE DESIGN              | $6,961.17 |
# | WOODEN ADVENT CALENDAR CREAM           | $6,946.42 |
# | TRIPLE PHOTO FRAME CORNICE             | $6,924.80 |
# | ENGLISH ROSE HOT WATER BOTTLE          | $6,903.62 |
# | SET OF 2 WOODEN MARKET CRATES          | $6,902.05 |
# | CHILDS BREAKFAST SET SPACEBOY          | $6,894.24 |
# | 3 TIER CAKE TIN GREEN AND CREAM        | $6,894.24 |
# | YOU'RE CONFUSING ME METAL SIGN         | $6,892.18 |
# | JUMBO BAG DOLLY GIRL DESIGN            | $6,891.28 |
# | BLACK/BLUE POLKADOT UMBRELLA           | $6,879.68 |
# | PLASTERS IN TIN SKULLS                 | $6,876.53 |
# | UNION STRIPE WITH FRINGE  HAMMOCK      | $6,862.67 |
# | CARRIAGE                               | $6,851.00 |
# | ROUND CAKE TIN VINTAGE RED             | $6,808.72 |
# | HOME SWEET HOME MUG                    | $6,800.52 |
# | SET 40 HEART SHAPE PETIT FOUR CASES    | $6,792.23 |
# | VICTORIAN SEWING BOX SMALL             | $6,788.24 |
# | RED METAL BOX TOP SECRET               | $6,779.00 |
# | HEART FILIGREE DOVE  SMALL             | $6,761.61 |
# | BEWARE OF THE CAT METAL SIGN           | $6,704.06 |
# | PICTURE FRAME WOOD TRIPLE PORTRAIT     | $6,686.72 |
# | DOLLY GIRL BABY GIFT SET               | $6,676.45 |
# | JINGLE BELL HEART ANTIQUE SILVER       | $6,668.46 |
# | PINK BABY BUNTING                      | $6,666.39 |
# | BINGO SET                              | $6,648.37 |
# | WALL ART CLASSIC PUDDINGS              | $6,638.01 |
# | CHILDRENS CUTLERY DOLLY GIRL           | $6,633.37 |
# | SET 6 PAPER TABLE LANTERN STARS        | $6,632.75 |
# | SET OF 72 PINK HEART PAPER DOILIES     | $6,623.65 |
# | CHRISTMAS LIGHTS 10 VINTAGE BAUBLES    | $6,580.16 |
# | RETROSPOT LARGE MILK JUG               | $6,557.67 |
# | PINK FAIRY CAKE CHILDRENS APRON        | $6,555.47 |
# | GIANT 50'S CHRISTMAS CRACKER           | $6,549.57 |
# | WHITE SPOT RED CERAMIC DRAWER KNOB     | $6,521.76 |
# | RED 3 PIECE RETROSPOT CUTLERY SET      | $6,494.66 |
# | 4 TRADITIONAL SPINNING TOPS            | $6,489.64 |
# | ANTIQUE SILVER TEA GLASS ETCHED        | $6,478.01 |
# | CANDLEHOLDER PINK HANGING HEART        | $6,471.24 |
# | ADVENT CALENDAR GINGHAM SACK           | $6,453.64 |
# | LARGE ZINC HEART WALL ORGANISER        | $6,431.11 |
# | DOORSTOP RETROSPOT HEART               | $6,428.58 |
# | VICTORIAN SEWING BOX MEDIUM            | $6,387.42 |
# | SET 2 TEA TOWELS I LOVE LONDON         | $6,381.53 |
# | VINTAGE DOILY JUMBO BAG RED            | $6,381.17 |
# | SET/10 PINK POLKADOT PARTY CANDLES     | $6,358.62 |
# | BISCUIT TIN 50'S CHRISTMAS             | $6,322.73 |
# | STRAWBERRY CHARLOTTE BAG               | $6,319.78 |
# | WOODEN HAPPY BIRTHDAY GARLAND          | $6,298.66 |
# | PANTRY WASHING UP BRUSH                | $6,298.41 |
# | RED RETROSPOT BOWL                     | $6,296.62 |
# | CHILDS BREAKFAST SET DOLLY GIRL        | $6,234.88 |
# | SET OF 2 TEA TOWELS APPLE AND PEARS    | $6,231.65 |
# | LANTERN CREAM GAZEBO                   | $6,224.67 |
# | FULL ENGLISH BREAKFAST PLATE           | $6,211.73 |
# | RED RETROSPOT SHOPPER BAG              | $6,211.47 |
# | LOVE SEAT ANTIQUE WHITE METAL          | $6,210.00 |
# | COFFEE MUG APPLES DESIGN               | $6,155.49 |
# | JINGLE BELL HEART DECORATION           | $6,129.26 |
# | SAVE THE PLANET MUG                    | $6,109.25 |
# | CHRISTMAS CRAFT TREE TOP ANGEL         | $6,078.93 |
# | RED RETROSPOT OVEN GLOVE               | $6,078.86 |
# | TEA TIME TEA TOWELS                    | $6,045.00 |
# | CLASSIC GLASS COOKIE JAR               | $6,024.60 |
# | TRADITIONAL NAUGHTS & CROSSES          | $6,024.31 |
# | REGENCY TEA PLATE PINK                 | $6,021.05 |
# | DOORMAT AIRMAIL                        | $6,001.90 |
# | VINTAGE SNAKES & LADDERS               | $5,986.10 |
# | SUKI  SHOULDER BAG                     | $5,962.67 |
# | SET 3 WICKER OVAL BASKETS W LIDS       | $5,961.25 |
# | VINTAGE DONKEY TAIL GAME               | $5,946.69 |
# | RED RETROSPOT SMALL MILK JUG           | $5,940.11 |
# | BLUE SPOT CERAMIC DRAWER KNOB          | $5,913.46 |
# | SET OF 6 TEA TIME BAKING CASES         | $5,912.52 |
# | BOX OF 6 CHRISTMAS CAKE DECORATIONS    | $5,889.38 |
# | WHITE SPOT BLUE CERAMIC DRAWER KNOB    | $5,847.71 |
# | RETROSPOT CHILDRENS APRON              | $5,835.52 |
# | DOORMAT TOPIARY                        | $5,832.50 |
# | RECYCLED ACAPULCO MAT TURQUOISE        | $5,816.56 |
# | PANTRY CHOPPING BOARD                  | $5,806.43 |
# | BUNDLE OF 3 ALPHABET EXERCISE BOOKS    | $5,801.50 |
# | VINTAGE CHRISTMAS STOCKING             | $5,784.17 |
# | PHOTO CUBE                             | $5,767.25 |
# | MINI LIGHTS WOODLAND MUSHROOMS         | $5,752.48 |
# | RED SPOT CERAMIC DRAWER KNOB           | $5,750.67 |
# | 3 DRAWER ANTIQUE WHITE WOOD CABINET    | $5,738.13 |
# | QUEENS GUARD COFFEE MUG                | $5,737.93 |
# | WOODEN OWLS LIGHT GARLAND              | $5,721.85 |
# | PHOTO FRAME 3 CLASSIC HANGING          | $5,687.95 |
# | PAPER BUNTING COLOURED LACE            | $5,661.05 |
# | HOT WATER BOTTLE BABUSHKA              | $5,625.38 |
# | FELTCRAFT PRINCESS OLIVIA DOLL         | $5,618.04 |
# | SET OF 4 JAM JAR MAGNETS               | $5,604.27 |
# | DOORMAT RESPECTABLE HOUSE              | $5,601.54 |
# | BOTANICAL GARDENS WALL CLOCK           | $5,585.72 |
# | PINK 3 PIECE POLKADOT CUTLERY SET      | $5,520.02 |
# | SKULL LUNCH BOX WITH CUTLERY           | $5,510.54 |
# | NATURAL SLATE RECTANGLE CHALKBOARD     | $5,502.80 |
# | RED RETROSPOT PLATE                    | $5,488.20 |
# | CALENDAR PAPER CUT DESIGN              | $5,479.06 |
# | 3 STRIPEY MICE FELTCRAFT               | $5,478.97 |
# | ENAMEL MEASURING JUG CREAM             | $5,448.94 |
# | SOMBRERO                               | $5,447.35 |
# | VINTAGE CHRISTMAS GIFT SACK            | $5,441.36 |
# | FRYING PAN UNION FLAG                  | $5,430.73 |
# | PARISIENNE JEWELLERY DRAWER            | $5,430.68 |
# | RUSTIC  SEVENTEEN DRAWER SIDEBOARD     | $5,415.00 |
# | PACK OF 6 PANNETONE GIFT BOXES         | $5,405.98 |
# | LARGE IVORY HEART WALL ORGANISER       | $5,396.89 |
# | DOG BOWL CHASING BALL DESIGN           | $5,351.56 |
# | SMALL ZINC HEART WALL ORGANISER        | $5,350.67 |
# | HEART IVORY TRELLIS SMALL              | $5,345.23 |
# | 3 PIECE SPACEBOY COOKIE CUTTER SET     | $5,250.65 |
# | CERAMIC STRAWBERRY CAKE MONEY BANK     | $5,249.38 |
# | VINTAGE CREAM CAT FOOD CONTAINER       | $5,235.80 |
# | WALL ART STOP FOR TEA                  | $5,226.76 |
# | BREAD BIN DINER STYLE PINK             | $5,225.40 |
# | CHARLOTTE BAG PINK POLKADOT            | $5,216.89 |
# | PARTY METAL SIGN                       | $5,210.02 |
# | WELCOME  WOODEN BLOCK LETTERS          | $5,207.23 |
# | RECIPE BOX BLUE SKETCHBOOK DESIGN      | $5,195.03 |
# | HEART IVORY TRELLIS LARGE              | $5,185.06 |
# | DOORMAT MERRY CHRISTMAS RED            | $5,176.25 |
# | SET OF 6 NATIVITY MAGNETS              | $5,165.97 |
# | RED RETROSPOT MUG                      | $5,164.74 |
# | SMALL IVORY HEART WALL ORGANISER       | $5,153.93 |
# | SET OF 5 LUCKY CAT MAGNETS             | $5,152.54 |
# | BOX OF VINTAGE JIGSAW BLOCKS           | $5,116.74 |
# | HANGING METAL HEART LANTERN            | $5,101.74 |
# | CERAMIC CAKE STAND + HANGING CAKES     | $5,097.39 |
# | SET3 BOOK BOX GREEN GINGHAM FLOWER     | $5,062.68 |
# | SET 3 PAPER VINTAGE CHICK PAPER EGG    | $5,023.50 |
# | FELTCRAFT DOLL ROSIE                   | $5,022.10 |
# | VINYL RECORD FRAME SILVER              | $5,010.69 |
# | GUMBALL MAGAZINE RACK                  | $5,003.16 |
# | BREAD BIN DINER STYLE MINT             | $5,001.83 |
# | LIGHT GARLAND BUTTERFILES PINK         | $4,967.84 |
# | HOME SWEET HOME METAL SIGN             | $4,967.29 |
# | COFFEE MUG PEARS  DESIGN               | $4,964.00 |
# | BATH BUILDING BLOCK WORD               | $4,953.96 |
# | ANTIQUE GLASS DRESSING TABLE POT       | $4,942.66 |
# | REGENCY TEA STRAINER                   | $4,929.80 |
# | CHILDRENS APRON APPLES DESIGN          | $4,918.49 |
# | SCANDINAVIAN PAISLEY PICNIC BAG        | $4,908.92 |
# | FOOT STOOL HOME SWEET HOME             | $4,908.10 |
# | STRAWBERRY   PICNIC BAG                | $4,890.00 |
# | LANDMARK FRAME CAMDEN TOWN             | $4,883.73 |
# | PINK VINTAGE PAISLEY PICNIC BAG        | $4,866.05 |
# | COFFEE MUG CAT + BIRD DESIGN           | $4,862.10 |
# | I'M ON HOLIDAY METAL SIGN              | $4,861.56 |
# | SET OF 3 WOODEN HEART DECORATIONS      | $4,859.03 |
# | CHILDS BREAKFAST SET CIRCUS PARADE     | $4,856.93 |
# | JUMBO BAG CHARLIE AND LOLA TOYS        | $4,853.81 |
# | SET/10 BLUE POLKADOT PARTY CANDLES     | $4,824.30 |
# | LUNCH BAG PAISLEY PARK                 | $4,824.03 |
# | FELTCRAFT GIRL AMELIE KIT              | $4,819.70 |
# | LANDMARK FRAME COVENT GARDEN           | $4,812.05 |
# | LARGE CERAMIC TOP STORAGE JAR          | $4,811.94 |
# | POPPY'S PLAYHOUSE KITCHEN              | $4,807.47 |
# | PINK DRAWER KNOB ACRYLIC EDWARDIAN     | $4,804.65 |
# | AIRLINE BAG VINTAGE TOKYO 78           | $4,803.25 |
# | CIRCUS PARADE BABY GIFT SET            | $4,802.54 |
# | CHRISTMAS TOILET ROLL                  | $4,801.85 |
# | FILIGRIS HEART WITH BUTTERFLY          | $4,794.42 |
# | WALL ART BIG LOVE                      | $4,777.43 |
# | SET OF 5 PANCAKE DAY MAGNETS           | $4,771.76 |
# | PINK HEART SHAPE EGG FRYING PAN        | $4,761.78 |
# | RED RETROSPOT BUTTER DISH              | $4,758.75 |
# | 5 HOOK HANGER RED MAGIC TOADSTOOL      | $4,753.29 |
# | PANTRY MAGNETIC  SHOPPING LIST         | $4,721.87 |
# | BISCUIT TIN VINTAGE CHRISTMAS          | $4,718.32 |
# | LANDMARK FRAME OXFORD STREET           | $4,718.07 |
# | CHRISTMAS CRAFT WHITE FAIRY            | $4,688.10 |
# | LANDMARK FRAME NOTTING HILL            | $4,680.61 |
# | VINTAGE CHRISTMAS TABLECLOTH           | $4,675.66 |
# | 36 PENCILS TUBE RED RETROSPOT          | $4,661.83 |
# | EDWARDIAN PARASOL PINK                 | $4,653.79 |
# | PINK PARTY BAGS                        | $4,624.30 |
# | LANDMARK FRAME LONDON BRIDGE           | $4,616.41 |
# | ABC TREASURE BOOK BOX                  | $4,616.18 |
# | WOODEN SKITTLES GARDEN SET             | $4,606.56 |
# | POPPY'S PLAYHOUSE BEDROOM              | $4,590.60 |
# | PLAYING CARDS KEEP CALM & CARRY ON     | $4,589.38 |
# | CABIN BAG VINTAGE RETROSPOT            | $4,584.77 |
# | WASHROOM METAL SIGN                    | $4,583.09 |
# | PINK POLKADOT BOWL                     | $4,576.26 |
# | HEART FILIGREE DOVE LARGE              | $4,559.55 |
# | HAND WARMER BABUSHKA DESIGN            | $4,521.78 |
# | RIBBON REEL STRIPES DESIGN             | $4,513.47 |
# | PICNIC BOXES SET OF 3 RETROSPOT        | $4,507.06 |
# | CERAMIC HEART FAIRY CAKE MONEY BANK    | $4,505.74 |
# | BLUE 3 PIECE POLKADOT CUTLERY SET      | $4,504.50 |
# | SPACEBOY MINI BACKPACK                 | $4,498.37 |
# | PURPLE DRAWERKNOB ACRYLIC EDWARDIAN    | $4,497.40 |
# | BULL DOG BOTTLE OPENER                 | $4,494.64 |
# | PICTURE DOMINOES                       | $4,484.97 |
# | CUPCAKE LACE PAPER SET 6               | $4,478.65 |
# | LAUNDRY 15C METAL SIGN                 | $4,476.24 |
# | TREASURE ISLAND BOOK BOX               | $4,465.75 |
# | SET OF 36 TEATIME PAPER DOILIES        | $4,465.37 |
# | BIRD HOUSE HOT WATER BOTTLE            | $4,447.77 |
# | PAPER BUNTING VINTAGE PAISLEY          | $4,442.68 |
# | CAMOUFLAGE LED TORCH                   | $4,434.87 |
# | PHARMACIE FIRST AID TIN                | $4,403.94 |
# | PACK OF 72 RETROSPOT CAKE CASES        | $4,403.90 |
# | PACK OF SIX LED TEA LIGHTS             | $4,399.27 |
# | TREASURE TIN GYMKHANA DESIGN           | $4,390.11 |
# | TRADITIONAL PICK UP STICKS GAME        | $4,372.62 |
# | ROLL WRAP 50'S CHRISTMAS               | $4,357.22 |
# | TRADITIONAL CHRISTMAS RIBBONS          | $4,329.13 |
# | REGENCY SUGAR TONGS                    | $4,310.98 |
# | VINTAGE DOILY DELUXE SEWING KIT        | $4,294.49 |
# | SKULL SHOULDER BAG                     | $4,290.87 |
# | SET OF 3 CAKE TINS SKETCHBOOK          | $4,257.27 |
# | BLACK KITCHEN SCALES                   | $4,225.43 |
# | PACK 3 BOXES BIRD PANNETONE            | $4,188.94 |
# | RECYCLED ACAPULCO MAT GREEN            | $4,187.16 |
# | PARISIENNE CURIO CABINET               | $4,180.22 |
# | SET OF 3 HANGING OWLS OLLIE BEAK       | $4,174.74 |
# | POTTERING MUG                          | $4,172.07 |
# | WALL ART BICYCLE SAFETY                | $4,128.71 |
# | WICKER STAR                            | $4,126.00 |
# | CLASSIC CAFE SUGAR DISPENSER           | $4,125.90 |
# | CHILDREN'S APRON DOLLY GIRL            | $4,108.56 |
# | ROUND SNACK BOXES SET OF 4 SKULLS      | $4,106.52 |
# | SET OF 6 HERB TINS SKETCHBOOK          | $4,101.45 |
# | HOLIDAY FUN LUDO                       | $4,082.59 |
# | PINK FLORAL FELTCRAFT SHOULDER BAG     | $4,074.67 |
# | SET OF 4 ENGLISH ROSE PLACEMATS        | $4,066.22 |
# | STRAWBERRY FAIRY CAKE TEAPOT           | $4,042.00 |
# | ROUND CAKE TIN VINTAGE GREEN           | $4,038.50 |
# | OWL DOORSTOP                           | $4,035.21 |
# | ANTIQUE GLASS PEDESTAL BOWL            | $4,028.15 |
# | VINTAGE CREAM 3 BASKET CAKE STAND      | $4,025.99 |
# | PARISIENNE KEY CABINET                 | $4,023.55 |
# | TRADITIONAL WOODEN CATCH CUP GAME      | $4,016.06 |
# | SCANDINAVIAN REDS RIBBONS              | $4,010.56 |
# | GLASS BON BON JAR                      | $4,005.64 |
# | SET OF 36 DOILIES PANTRY DESIGN        | $3,983.60 |
# | CHRISTMAS LIGHTS 10 SANTAS             | $3,973.90 |
# | I LOVE LONDON BABY GIFT SET            | $3,971.56 |
# | WATERING CAN BLUE ELEPHANT             | $3,965.08 |
# | CHILDRENS CUTLERY CIRCUS PARADE        | $3,960.27 |
# | SET/6 PINK  BUTTERFLY T-LIGHTS         | $3,940.79 |
# | VINTAGE CHRISTMAS CAKE FRILL           | $3,933.54 |
# | BLUE POLKADOT BOWL                     | $3,927.15 |
# | NOVELTY BISCUITS CAKE STAND 3 TIER     | $3,919.85 |
# | RED RETROSPOT OVEN GLOVE DOUBLE        | $3,909.63 |
# | 36 FOIL HEART CAKE CASES               | $3,908.84 |
# | JUMBO BAG SCANDINAVIAN PAISLEY         | $3,908.62 |
# | RED RETROSPOT CHILDRENS UMBRELLA       | $3,908.57 |
# | HEART SHAPED HOLLY WREATH              | $3,908.24 |
# | EASTER CRAFT 4 CHICKS                  | $3,905.75 |
# | ROLL WRAP VINTAGE CHRISTMAS            | $3,901.00 |
# | GLASS APOTHECARY BOTTLE PERFUME        | $3,899.16 |
# | PANTRY SCRUBBING BRUSH                 | $3,883.67 |
# | LARGE RED RETROSPOT WINDMILL           | $3,877.09 |
# | BOYS VINTAGE TIN SEASIDE BUCKET        | $3,876.31 |
# | ENCHANTED BIRD COATHANGER 5 HOOK       | $3,872.36 |
# | FOOD CONTAINER SET 3 LOVE HEART        | $3,865.81 |
# | RECYCLED ACAPULCO MAT RED              | $3,863.84 |
# | LANDMARK FRAME BAKER STREET            | $3,855.31 |
# | HOME SWEET HOME BLACKBOARD             | $3,848.76 |
# | RETRO COFFEE MUGS ASSORTED             | $3,844.81 |
# | CAKE PLATE LOVEBIRD WHITE              | $3,830.46 |
# | LARGE CAKE TOWEL PINK SPOTS            | $3,822.45 |
# | PAINT YOUR OWN CANVAS SET              | $3,815.11 |
# | BISCUIT TIN VINTAGE RED                | $3,809.92 |
# | FELTCRAFT DOLL EMILY                   | $3,797.46 |
# | LUNCH BAG SUKI  DESIGN                 | $3,791.86 |
# | BLUE POLKADOT PLATE                    | $3,782.74 |
# | METAL SIGN HER DINNER IS SERVED        | $3,779.70 |
# | PEG BAG APPLES DESIGN                  | $3,775.26 |
# | ILLUSTRATED CAT BOWL                   | $3,773.67 |
# | SMALL RED RETROSPOT WINDMILL           | $3,766.93 |
# | RED RETROSPOT TRADITIONAL TEAPOT       | $3,756.79 |
# | FOOD COVER WITH BEADS SET 2            | $3,743.04 |
# | GLASS  BEURRE DISH                     | $3,721.63 |
# | DOORMAT VINTAGE LEAF                   | $3,720.15 |
# | 16 PIECE CUTLERY SET PANTRY DESIGN     | $3,719.87 |
# | CINDERELLA CHANDELIER                  | $3,717.56 |
# | GYMKHANA TREASURE BOOK BOX             | $3,713.40 |
# | CREAM SWEETHEART EGG HOLDER            | $3,708.52 |
# | VINTAGE BLUE KITCHEN CABINET           | $3,685.00 |
# | FIRST AID TIN                          | $3,676.60 |
# | IVORY GIANT GARDEN THERMOMETER         | $3,674.70 |
# | RED RETROSPOT SUGAR JAM BOWL           | $3,666.87 |
# | CHRISTMAS STAR WISH LIST CHALKBOARD    | $3,663.15 |
# | RIBBON REEL SNOWY VILLAGE              | $3,650.59 |
# | STORAGE TIN VINTAGE DOILY              | $3,646.92 |
# | FAIRY TALE COTTAGE NIGHTLIGHT          | $3,626.45 |
# | CAKE STAND 3 TIER MAGIC GARDEN         | $3,624.60 |
# | DRAWER KNOB CRACKLE GLAZE IVORY        | $3,608.58 |
# | LARGE ANTIQUE WHITE PHOTO FRAME        | $3,599.00 |
# | CHARLIE AND LOLA FIGURES TINS          | $3,587.19 |
# | SET OF 16 VINTAGE PISTACHIO CUTLERY    | $3,585.99 |
# | ZINC HERB GARDEN CONTAINER             | $3,585.39 |
# | GIN AND TONIC MUG                      | $3,585.19 |
# | GREEN METAL BOX ARMY SUPPLIES          | $3,583.62 |
# | LARGE CAKE STAND  HANGING STRAWBERY    | $3,579.01 |
# | S/6 WOODEN SKITTLES IN COTTON BAG      | $3,572.05 |
# | BABUSHKA LIGHTS STRING OF 10           | $3,566.09 |
# | RETROSPOT LAMP                         | $3,561.34 |
# | TRADTIONAL ALPHABET STAMP SET          | $3,539.14 |
# | VINTAGE PAISLEY STATIONERY SET         | $3,529.12 |
# | MISTLETOE HEART WREATH GREEN           | $3,526.79 |
# | LARGE HEART MEASURING SPOONS           | $3,524.61 |
# | WALL ART ONLY ONE PERSON               | $3,520.39 |
# | FOUR HOOK  WHITE LOVEBIRDS             | $3,514.95 |
# | DOORMAT PEACE ON EARTH BLUE            | $3,503.16 |
# | SET OF 6 T-LIGHTS SANTA                | $3,496.68 |
# | GIRLS VINTAGE TIN SEASIDE BUCKET       | $3,492.15 |
# | TRAY, BREAKFAST IN BED                 | $3,491.86 |
# | SET OF 36 PAISLEY FLOWER DOILIES       | $3,451.02 |
# | PINK  POLKADOT PLATE                   | $3,449.60 |
# | CAMOUFLAGE DESIGN TEDDY                | $3,448.05 |
# | WHITE ROCKING HORSE HAND PAINTED       | $3,433.42 |
# | RED BABY BUNTING                       | $3,429.97 |
# | ANTIQUE TALL SWIRLGLASS TRINKET POT    | $3,426.06 |
# | SET 10 NIGHT OWL LIGHTS                | $3,410.91 |
# | BUNDLE OF 3 RETRO NOTE BOOKS           | $3,407.87 |
# | RIBBON REEL CHRISTMAS SOCK BAUBLE      | $3,374.96 |
# | PACK 3 BOXES CHRISTMAS PANNETONE       | $3,361.77 |
# | FRENCH ENAMEL CANDLEHOLDER             | $3,352.42 |
# | TEA TIME KITCHEN APRON                 | $3,346.81 |
# | GLASS APOTHECARY BOTTLE TONIC          | $3,343.05 |
# | SET OF 5 MINI GROCERY MAGNETS          | $3,331.77 |
# | MIRRORED DISCO BALL                    | $3,326.10 |
# | SET OF 12 FORK CANDLES                 | $3,319.61 |
# | SET 10 LIGHTS NIGHT OWL                | $3,317.47 |
# | LARGE DECO JEWELLERY STAND             | $3,314.94 |
# | ANTIQUE SILVER BAUBLE LAMP             | $3,312.43 |
# | COFFEE MUG DOG + BALL DESIGN           | $3,305.08 |
# | FINE WICKER HEART                      | $3,304.23 |
# | SET OF 9 HEART SHAPED BALLOONS         | $3,297.00 |
# | IVORY WICKER HEART LARGE               | $3,291.95 |
# | ROTATING LEAVES T-LIGHT HOLDER         | $3,289.96 |
# | PARISIENNE SEWING BOX                  | $3,289.76 |
# | GAOLERS KEYS DECORATIVE GARDEN         | $3,283.96 |
# | 3 HOOK HANGER MAGIC GARDEN             | $3,280.11 |
# | BUFFALO BILL TREASURE BOOK BOX         | $3,277.04 |
# | SET 3 WICKER STORAGE BASKETS           | $3,275.20 |
# | WOODLAND MINI BACKPACK                 | $3,266.13 |
# | SET 3 SONG BIRD PAPER EGGS ASSORTED    | $3,259.61 |
# | GLASS APOTHECARY BOTTLE ELIXIR         | $3,258.95 |
# | ENAMEL WATERING CAN CREAM              | $3,256.19 |
# | SET OF 16 VINTAGE ROSE CUTLERY         | $3,251.88 |
# | POTTING SHED TEA MUG                   | $3,245.80 |
# | WATERING CAN PINK BUNNY                | $3,243.89 |
# | 20 DOLLY PEGS RETROSPOT                | $3,231.53 |
# | METAL SIGN DROP YOUR PANTS             | $3,221.81 |
# | DOORMAT CHRISTMAS VILLAGE              | $3,221.18 |
# | FELTCRAFT GIRL NICOLE KIT              | $3,218.56 |
# | RIBBON REEL HEARTS DESIGN              | $3,218.13 |
# | SET OF 4 KNICK KNACK TINS POPPIES      | $3,207.60 |
# | RECYCLED ACAPULCO MAT PINK             | $3,188.06 |
# | SET/3 VANILLA SCENTED CANDLE IN BOX    | $3,186.50 |
# | RED GINGHAM ROSE JEWELLERY BOX         | $3,186.34 |
# | EMBOSSED GLASS TEALIGHT HOLDER         | $3,183.01 |
# | POPPY'S PLAYHOUSE LIVINGROOM           | $3,179.77 |
# | SMALL POPCORN HOLDER                   | $3,174.83 |
# | RECYCLED ACAPULCO MAT BLUE             | $3,173.73 |
# | ROLL WRAP VINTAGE SPOT                 | $3,150.80 |
# | GLASS CLOCHE SMALL                     | $3,131.02 |
# | GLASS JAR ENGLISH CONFECTIONERY        | $3,117.55 |
# | FLORAL FOLK STATIONERY SET             | $3,111.14 |
# | BUTTON BOX                             | $3,111.01 |
# | GREEN 3 PIECE POLKADOT CUTLERY SET     | $3,110.91 |
# | MINT DINER WALL CLOCK                  | $3,108.41 |
# | MINI WOODEN HAPPY BIRTHDAY GARLAND     | $3,108.22 |
# | CHARLIE+LOLA PINK HOT WATER BOTTLE     | $3,107.38 |
# | RETROSPOT RED WASHING UP GLOVES        | $3,090.96 |
# | VINTAGE  2 METER FOLDING RULER         | $3,075.37 |
# | DINOSAUR LUNCH BOX WITH CUTLERY        | $3,072.26 |
# | HOME SWEET HOME CUSHION COVER          | $3,070.54 |
# | STRAWBERRY SHOPPER BAG                 | $3,068.48 |
# | BELLE JARDINIERE CUSHION COVER         | $3,054.05 |
# | SWEETHEART 3 TIER CAKE STAND           | $3,042.63 |
# | SPACEBOY BEAKER                        | $3,031.45 |
# | SET OF 6 T-LIGHTS SNOWMEN              | $3,030.93 |
# | SET OF SALT AND PEPPER TOADSTOOLS      | $3,029.10 |
# | GREEN CHRISTMAS TREE CARD HOLDER       | $3,010.64 |
# | TABLECLOTH RED APPLES DESIGN           | $3,007.48 |
# | DOILEY STORAGE TIN                     | $3,004.46 |
# | WALL ART DOG LICENCE                   | $3,000.57 |
# | DRAWER KNOB CERAMIC IVORY              | $2,992.81 |
# | ALPHABET STENCIL CRAFT                 | $2,983.72 |
# | OFFICE MUG WARMER BLACK+SILVER         | $2,981.28 |
# | GLITTER BUTTERFLY CLIPS                | $2,971.35 |
# | HAPPY STENCIL CRAFT                    | $2,963.21 |
# | CITRONELLA CANDLE GARDEN POT           | $2,961.61 |
# | CHILDREN'S SPACEBOY MUG                | $2,958.76 |
# | RETROSPOT GIANT TUBE MATCHES           | $2,955.00 |
# | WOODLAND PARTY BAG + STICKER SET       | $2,937.23 |
# | GLASS CLOCHE LARGE                     | $2,934.53 |
# | SET OF 4 NAPKIN CHARMS CUTLERY         | $2,926.87 |
# | TROPICAL  HONEYCOMB PAPER GARLAND      | $2,922.50 |
# | FLOWERS CHANDELIER T-LIGHT HOLDER      | $2,898.12 |
# | BISCUIT TIN VINTAGE GREEN              | $2,897.98 |
# | VINTAGE UNION JACK APRON               | $2,897.12 |
# | VINTAGE  2 METRE FOLDING RULER         | $2,885.91 |
# | DOORMAT VINTAGE LEAVES DESIGN          | $2,881.18 |
# | SET OF 3 BLACK FLYING DUCKS            | $2,880.31 |
# | DECORATIVE WICKER HEART LARGE          | $2,866.60 |
# | RIBBON REEL LACE DESIGN                | $2,864.41 |
# | RETROSPOT PADDED SEAT CUSHION          | $2,853.52 |
# | SET OF 4 KNICK KNACK TINS LEAF         | $2,842.16 |
# | S/4 CACTI CANDLES                      | $2,834.92 |
# | WHITE WICKER STAR                      | $2,828.91 |
# | STOOL HOME SWEET HOME                  | $2,823.08 |
# | TEA TIME OVEN GLOVE                    | $2,814.29 |
# | ROSE CARAVAN DOORSTOP                  | $2,810.22 |
# | ENAMEL WASH BOWL CREAM                 | $2,807.05 |
# | GREEN VINTAGE SPOT BEAKER              | $2,804.15 |
# | CHEST OF DRAWERS GINGHAM HEART         | $2,801.12 |
# | BLUE PARTY BAGS                        | $2,797.12 |
# | BAKING MOULD HEART MILK CHOCOLATE      | $2,796.50 |
# | PINK VINTAGE SPOT BEAKER               | $2,792.74 |
# | VICTORIAN  METAL POSTCARD SPRING       | $2,791.11 |
# |  DOLLY GIRL BEAKER                     | $2,783.99 |
# | BLUE GIANT GARDEN THERMOMETER          | $2,763.42 |
# | HANGING METAL STAR LANTERN             | $2,752.60 |
# | TREASURE TIN BUFFALO BILL              | $2,747.34 |
# | CERAMIC CHERRY CAKE MONEY BANK         | $2,746.09 |
# | CHEST NATURAL WOOD 20 DRAWERS          | $2,745.00 |
# | 12 MESSAGE CARDS WITH ENVELOPES        | $2,742.08 |
# | RED ROCKING HORSE HAND PAINTED         | $2,737.82 |
# | RED DRAWER KNOB ACRYLIC EDWARDIAN      | $2,723.55 |
# | SWEETHEART WIRE MAGAZINE RACK          | $2,721.30 |
# | PLAYING CARDS JUBILEE UNION JACK       | $2,716.59 |
# | TOY TIDY SPACEBOY                      | $2,697.71 |
# | BUNDLE OF 3 SCHOOL EXERCISE BOOKS      | $2,697.55 |
# | CUPBOARD 3 DRAWER MA CAMPAGNE          | $2,696.33 |
# | GREEN GIANT GARDEN THERMOMETER         | $2,693.08 |
# | SPACEBOY CHILDRENS BOWL                | $2,691.89 |
# | SINGLE ANTIQUE ROSE HOOK IVORY         | $2,691.30 |
# | CHILDRENS DOLLY GIRL MUG               | $2,683.53 |
# | GLITTER HANGING BUTTERFLY STRING       | $2,678.99 |
# | 6 EGG HOUSE PAINTED WOOD               | $2,678.84 |
# | MODERN FLORAL STATIONERY SET           | $2,677.00 |
# | MA CAMPAGNE CUTLERY BOX                | $2,676.75 |
# | REGENCY CAKE SLICE                     | $2,668.97 |
# | DOLLY GIRL MINI BACKPACK               | $2,663.82 |
# | WHITE LOVEBIRD LANTERN                 | $2,661.36 |
# | BLUE VINTAGE SPOT BEAKER               | $2,651.97 |
# | WATERING CAN GREEN DINOSAUR            | $2,651.67 |
# | GARLAND WOODEN HAPPY EASTER            | $2,641.93 |
# | ROUND CONTAINER SET OF 5 RETROSPOT     | $2,630.62 |
# | PACK OF 6 SWEETIE GIFT BOXES           | $2,623.99 |
# | CARDHOLDER HOLLY WREATH METAL          | $2,617.72 |
# | UTILTY CABINET WITH HOOKS              | $2,610.29 |
# | TOTE BAG I LOVE LONDON                 | $2,608.29 |
# | WALL TIDY RETROSPOT                    | $2,606.54 |
# | HALL CABINET WITH 3 DRAWERS            | $2,603.53 |
# | HEART WREATH DECORATION WITH BELL      | $2,599.31 |
# | SILVER BELLS TABLE DECORATION          | $2,597.08 |
# | COTTON APRON PANTRY DESIGN             | $2,596.95 |
# | DOORMAT I LOVE LONDON                  | $2,591.66 |
# | DOORMAT WELCOME SUNRISE                | $2,588.43 |
# | IVORY WICKER HEART MEDIUM              | $2,587.95 |
# | TWO DOOR CURIO CABINET                 | $2,577.45 |
# | BAKING MOULD EASTER EGG MILK CHOC      | $2,577.18 |
# | RECYCLED ACAPULCO MAT LAVENDER         | $2,571.67 |
# | RIBBON REEL CHRISTMAS PRESENT          | $2,567.19 |
# | CREAM WALL PLANTER HEART SHAPED        | $2,564.34 |
# | TRIPLE HOOK ANTIQUE IVORY ROSE         | $2,559.45 |
# | STOP FOR TEA WALL ART                  | $2,554.85 |
# | SET/6 TURQUOISE BUTTERFLY T-LIGHTS     | $2,548.42 |
# | BLUE DRAWER KNOB ACRYLIC EDWARDIAN     | $2,543.64 |
# | 3 TRADITIONAl BISCUIT CUTTERS  SET     | $2,537.60 |
# | SET OF 3 WOODEN STOCKING DECORATION    | $2,534.90 |
# | RED RETROSPOT TEA CUP AND SAUCER       | $2,533.67 |
# | GREEN DRAWER KNOB ACRYLIC EDWARDIAN    | $2,531.44 |
# | MISTLETOE HEART WREATH CREAM           | $2,527.18 |
# | GLASS JAR DAISY FRESH COTTON WOOL      | $2,522.74 |
# | CERAMIC STRAWBERRY MONEY BOX           | $2,515.52 |
# | PINK DINER WALL CLOCK                  | $2,513.92 |
# | VANILLA SCENT CANDLE JEWELLED BOX      | $2,475.73 |
# | VINTAGE LEAF MAGNETIC NOTEPAD          | $2,468.54 |
# | BAKING MOULD CHOCOLATE CUPCAKES        | $2,466.62 |
# | SET OF 2 TRAYS HOME SWEET HOME         | $2,463.81 |
# | OVERNIGHT BAG VINTAGE ROSE PAISLEY     | $2,462.91 |
# | TOADSTOOL MONEY BOX                    | $2,461.88 |
# | DIAMANTE HEART SHAPED WALL MIRROR,     | $2,458.19 |
# | S/4 VALENTINE DECOUPAGE HEART BOX      | $2,443.04 |
# | KINGS CHOICE TEA CADDY                 | $2,440.77 |
# | GLASS STAR FROSTED T-LIGHT HOLDER      | $2,440.06 |
# | BLACK AND WHITE CAT BOWL               | $2,433.99 |
# | SINGLE HEART ZINC T-LIGHT HOLDER       | $2,431.40 |
# | FRENCH BATHROOM SIGN BLUE METAL        | $2,427.11 |
# | SET OF 3 WOODEN SLEIGH DECORATIONS     | $2,427.05 |
# | PINK OWL SOFT TOY                      | $2,422.01 |
# | PEARL CRYSTAL PUMPKIN T-LIGHT HLDR     | $2,399.86 |
# | BLUE SAVANNAH PICNIC HAMPER FOR 2      | $2,393.59 |
# | SHELF WITH 4 HOOKS HOME SWEET HOME     | $2,390.59 |
# | SPACEBOY CHILDRENS CUP                 | $2,382.33 |
# | RED REFECTORY CLOCK                    | $2,372.17 |
# | BICYCLE SAFTEY WALL ART                | $2,371.94 |
# | MAN FLU METAL SIGN                     | $2,370.11 |
# | AIRLINE BAG VINTAGE JET SET RED        | $2,368.98 |
# | BOX OF 6 ASSORTED COLOUR TEASPOONS     | $2,368.48 |
# | FRENCH WC SIGN BLUE METAL              | $2,358.40 |
# | PINK DOUGHNUT TRINKET POT              | $2,356.09 |
# | HEART MIRROR ANTIQUE WHITE             | $2,354.80 |
# | SET OF 10 LANTERNS FAIRY LIGHT STAR    | $2,343.49 |
# | ANTIQUE ALL GLASS CANDLESTICK          | $2,342.93 |
# | GINGHAM RECIPE BOOK BOX                | $2,339.15 |
# |  OVAL WALL MIRROR DIAMANTE             | $2,338.06 |
# | 36 PENCILS TUBE WOODLAND               | $2,331.14 |
# | HOME SWEET HOME KEY HOLDER             | $2,328.99 |
# | 12 EGG HOUSE PAINTED WOOD              | $2,328.06 |
# | KINGS CHOICE MUG                       | $2,322.53 |
# | RED HEART SHAPE LOVE BUCKET            | $2,316.70 |
# | SWEETHEART WIRE WALL TIDY              | $2,315.33 |
# | GINGHAM HEART  DOORSTOP RED            | $2,300.96 |
# | ENAMEL COLANDER CREAM                  | $2,296.38 |
# | 36 PENCILS TUBE SKULLS                 | $2,293.25 |
# | POTTING SHED TWINE                     | $2,274.89 |
# | TEA TIME TEAPOT IN GIFT BOX            | $2,256.37 |
# |  50'S CHRISTMAS GIFT BAG LARGE         | $2,253.99 |
# | VINTAGE BILLBOARD TEA MUG              | $2,251.77 |
# | LE JARDIN BOTANIQUE CUSHION COVER      | $2,225.55 |
# | DECORATIVE WICKER HEART MEDIUM         | $2,224.63 |
# | VINTAGE RED ENAMEL TRIM JUG            | $2,224.11 |
# | ROLL WRAP 50'S RED CHRISTMAS           | $2,223.42 |
# | SET OF 6 T-LIGHTS TOADSTOOLS           | $2,220.92 |
# | SET OF 3 WOODEN TREE DECORATIONS       | $2,219.50 |
# | BLUE COAT RACK PARIS FASHION           | $2,214.88 |
# | CLASSIC FRENCH STYLE BASKET NATURAL    | $2,213.42 |
# | POLYESTER FILLER PAD 40x40cm           | $2,205.45 |
# | BLACK AND WHITE DOG BOWL               | $2,200.08 |
# | MAKE YOUR OWN FLOWERPOWER CARD KIT     | $2,194.31 |
# | SET 36 COLOUR PENCILS SPACEBOY         | $2,192.76 |
# | DRAWER KNOB CRACKLE GLAZE GREEN        | $2,191.72 |
# | CAKE STAND WHITE TWO TIER LACE         | $2,189.26 |
# | STRAWBERRY RAFFIA FOOD COVER           | $2,185.32 |
# | CHOCOLATE BOX RIBBONS                  | $2,176.13 |
# | RED RETROSPOT APRON                    | $2,175.16 |
# | RIBBON REEL MAKING SNOWMEN             | $2,169.91 |
# | GROW YOUR OWN BASIL IN ENAMEL MUG      | $2,169.29 |
# | LARGE CAKE TOWEL CHOCOLATE SPOTS       | $2,165.14 |
# | SMALL PARISIENNE HEART PHOTO FRAME     | $2,159.74 |
# | TOADSTOOL BEDSIDE LIGHT                | $2,153.85 |
# | BIRDHOUSE GARDEN MARKER                | $2,153.36 |
# | DRAWER KNOB CRACKLE GLAZE BLUE         | $2,148.53 |
# | CERAMIC CAKE DESIGN SPOTTED MUG        | $2,146.35 |
# | 6 RIBBONS ELEGANT CHRISTMAS            | $2,143.85 |
# | SMALL RED RETROSPOT MUG IN BOX         | $2,141.60 |
# | RED GINGHAM TEDDY BEAR                 | $2,133.67 |
# | PARTY CONES CANDY ASSORTED             | $2,127.53 |
# | WOODLAND  HEIGHT CHART STICKERS        | $2,124.93 |
# | CERAMIC CAKE BOWL + HANGING CAKES      | $2,111.75 |
# | ASSTD DESIGN RACING CAR PEN            | $2,111.03 |
# ...
# | TUMBLER BAROQUE                        | $17.37 |
# | ENGLISH ROSE SCENTED HANGING HEART     | $17.00 |
# | VINTAGE BEAD PINK JEWEL BOX            | $17.00 |
# | GLASS BEAD HOOP NECKLACE BLACK         | $17.00 |
# | MINT DINER CLOCK                       | $17.00 |
# | GLASS BELL JAR LARGE                   | $17.00 |
# | *Boombox Ipod Classic                  | $16.98 |
# | *USB Office Mirror Ball                | $16.94 |
# | Dad's Cab Electronic Meter             | $16.94 |
# | NEW BAROQUE B'FLY NECKLACE PINK        | $16.82 |
# | NEW BAROQUE B'FLY NECKLACE MONTANA     | $16.81 |
# | PINK POODLE HANGING DECORATION         | $16.80 |
# | SILVER/BLACK PENDANT ORBIT NECKLACE    | $16.64 |
# | HAYNES CAMPER SHOULDER BAG             | $16.63 |
# | PARTY CONES CANDY TREE DECORATION      | $16.58 |
# | MINI FUNKY DESIGN TAPES                | $16.42 |
# | PARTY PIZZA DISH PINK POLKADOT         | $16.42 |
# | CHILDS GARDEN TROWEL PINK              | $16.36 |
# | CRYSTAL STILETTO PHONE CHARM           | $16.36 |
# | PINK COMBO MINI CRYSTALS NECKLACE      | $16.31 |
# | PARTY INVITES DINOSAURS                | $16.30 |
# | RED SPOT PAPER GIFT BAG                | $16.30 |
# | CUTE CATS TAPE                         | $16.30 |
# | VINTAGE BEAD PINK SHADE                | $16.25 |
# | PLAYING CARDS VINTAGE DOILEY           | $16.25 |
# | BLUE HOLE PUNCH                        | $16.25 |
# | 3 WICK CHRISTMAS BRIAR CANDLE          | $15.97 |
# | BLUE SHARK HELICOPTER                  | $15.90 |
# | OCEAN STRIPE HAMMOCK                   | $15.90 |
# | GLASS BELL JAR SMALL                   | $15.80 |
# | OOH LA LA DOGS COLLAR                  | $15.79 |
# | GOLD FLOWER CUSHION COVER              | $15.60 |
# | FUSCHIA VOILE POINTY SHOE DEC          | $15.60 |
# | BLUE NETTING STORAGE HANGER            | $15.60 |
# | FLOWER FAIRY 5 SUMMER DRAW LINERS      | $15.30 |
# | ACRYLIC JEWEL SNOWFLAKE,PINK           | $15.30 |
# | BAKING MOULD TOFFEE CUP  CHOCOLATE     | $15.30 |
# | LIGHT TOPAZ TEAL/AQUA COL NECKLACE     | $15.16 |
# | PINK SWEETIE NECKLACE                  | $15.12 |
# | PINK CHRISTMAS FLOCK DROPLET           | $15.02 |
# | PAINTED HEART WREATH WITH BELL         | $15.00 |
# | SET OF 6 EASTER RAINBOW CHICKS         | $15.00 |
# | 3 PINK HEN+CHICKS IN BASKET            | $15.00 |
# | PINK/WHITE GLASS DEMI CHOKER           | $15.00 |
# | PAINTED SEA SHELL METAL WINDCHIME      | $15.00 |
# | ICON MUG REVOLUTIONARY                 | $15.00 |
# | ENAMEL MUG PANTRY                      | $15.00 |
# | LETTER "I" BLING KEY RING              | $15.00 |
# | ENVELOPE 50 BLOSSOM IMAGES             | $15.00 |
# | SILVER 2 STRAND NECKLACE-LEAF CHARM    | $15.00 |
# | PINK FLOCK PHOTO FRAME                 | $15.00 |
# | PINK FLOCK SUEDE CUSHION COVER         | $15.00 |
# | RUBY GLASS CLUSTER NECKLACE            | $15.00 |
# | BAROQUE BUTTERFLY EARRINGS CRYSTAL     | $14.96 |
# | FAIRY CAKE NOTEBOOK A5 SIZE            | $14.94 |
# | WHITE WITH METAL BAG CHARM             | $14.85 |
# | GREEN WITH METAL BAG CHARM             | $14.85 |
# | CURIOUS IMAGES SCRAP BOOK SET          | $14.85 |
# | SMALL PINK MAGIC CHRISTMAS TREE        | $14.85 |
# | SET 4 NURSERY DES ROUND BOXES          | $14.75 |
# | CROCHET ROSE DES CLOTHES HANGER        | $14.75 |
# | CHILDS GARDEN FORK BLUE                | $14.70 |
# | PARTY PIZZA DISH RED RETROSPOT         | $14.70 |
# | GREEN METAL SWINGING BUNNY             | $14.67 |
# | PEARL AND CHERRY QUARTZ BRACLET        | $14.54 |
# | GLASS BEAD HOOP EARRINGS GREEN         | $14.50 |
# | PINK BERTIE GLASS BEAD BAG CHARM       | $14.44 |
# | FREESTYLE CANVAS ART PICTURE           | $14.15 |
# | CRACKED GLAZE NECKLACE BROWN           | $14.14 |
# | WALL ART , THE MAGIC FOREST            | $13.90 |
# | LETTER "J" BLING KEY RING              | $13.75 |
# | BLACK VINT ART DEC CRYSTAL BRACELET    | $13.50 |
# | SILVER AND BLACK ORBIT NECKLACE        | $13.35 |
# | SET 10 CARDS MAGICAL TREE 17086        | $13.32 |
# | SET 10 CARDS CHRISTMAS TREE 16955      | $13.32 |
# | SET 10 CARDS HATS & STOCKINGS 17081    | $13.28 |
# | YELLOW FELT HANGING HEART W FLOWER     | $13.22 |
# | GREEN/BLUE CERAMIC CANDLE HOLDER       | $13.20 |
# | PARTY PIZZA DISH GREEN POLKADOT        | $13.10 |
# | PINK TALL PORCELAIN T-LIGHT HOLDER     | $12.75 |
# | CAMOUFLAGE DOG COLLAR                  | $12.72 |
# | POTTING SHED SOW 'N' GROW SET          | $12.72 |
# | FRESHWATER PEARL BRACELET IVORY        | $12.70 |
# | BLUE TEATIME PRINT BOWL                | $12.50 |
# | MARIE ANTOIENETT TRINKET BOX GOLD      | $12.50 |
# | FILIGREE DIAMANTE CHAIN                | $12.48 |
# | HYACINTH BULB T-LIGHT CANDLES          | $12.46 |
# | SET 10 CARDS JINGLE BELLS 17217        | $12.45 |
# | PURPLE CHUNKY GLASS+BEAD NECKLACE      | $11.95 |
# | LASER CUT MULTI STRAND NECKLACE        | $11.95 |
# | BLUE GINGHAM ROSE CUSHION COVER        | $11.90 |
# | PINK BAROQUE FLOCK CANDLE HOLDER       | $11.90 |
# | FLOWER FAIRY INCENSE BOUQUET           | $11.83 |
# | BLUE BREAKFAST CUP AND SAUCER          | $11.80 |
# | HOUSE SHAPE PENCIL SHARPENER           | $11.72 |
# | BLUE CHENILLE SHAGGY CUSHION COVER     | $11.70 |
# | SET 10 CARDS 12 DAYS OF XMAS 17059     | $11.64 |
# | SET 10 CARDS XMAS CHOIR 17068          | $11.64 |
# | AMETHYST 3 BEAD DROP EARRINGS          | $11.60 |
# | SET/4 GARDEN ROSE DINNER CANDLE        | $11.55 |
# | RETRO PLASTIC DAISY TRAY               | $11.47 |
# | PINK CRYSTAL SKULL PHONE CHARM         | $11.47 |
# | BLUE/GREEN SHELL NECKLACE W PENDANT    | $11.46 |
# | CLEAR CRYSTAL STAR PHONE CHARM         | $11.44 |
# | SET/3 RABBITS FLOWER SKIPPPING ROPE    | $11.41 |
# | LETTER "G" BLING KEY RING              | $11.25 |
# | LETTER "H" BLING KEY RING              | $11.25 |
# | PACK OF 12 TRADITIONAL CRAYONS         | $11.25 |
# | POCKET MIRROR WOODLAND                 | $11.25 |
# | FOOD COVER WITH BEADS , SET 2 SIZES    | $11.25 |
# | GOLD FABRIC MIRROR                     | $11.22 |
# | BAROQUE BUTTERFLY EARRINGS PINK        | $11.19 |
# | CARTOON  PENCIL SHARPENERS             | $10.55 |
# | CRACKED GLAZE EARRINGS BROWN           | $10.05 |
# | TINY CRYSTAL BRACELET BLUE             | $10.04 |
# | ZINC STAR T-LIGHT HOLDER               | $10.00 |
# | CRACKED GLAZE EARRINGS IVORY           | $9.99 |
# | SET 10 CARD PERFECT NATIVITY 17089     | $9.96 |
# | SET 10 CARDS POINSETTIA 17093          | $9.96 |
# | S/2 BEACH HUT TREASURE CHESTS          | $9.95 |
# | SET/4 2 TONE EGG SHAPE MIXING BOWLS    | $9.95 |
# | BOXED GLASS ASHTRAY                    | $9.94 |
# | PURPLE/BLUE CERAMIC CANDLE HOLDER      | $9.88 |
# | FROSTED WHITE BASE                     | $9.87 |
# | PARTY PIZZA DISH BLUE POLKADOT         | $9.87 |
# | COLUMBIAN CANDLE ROUND                 | $9.81 |
# | PAISLEY PATTERN  STICKERS              | $9.81 |
# | WOODLAND SMALL PINK FELT HEART         | $9.78 |
# | BLACK GLASS/SHELL/PEARL NECKLACE       | $9.15 |
# | FOLDING SHOE TIDY                      | $8.85 |
# | VINTAGE NOTEBOOK BEAUTY GIRL           | $8.85 |
# | RED ROSE AND LACE C/COVER              | $8.85 |
# | BLACK DIAMOND CLUSTER EARRINGS         | $8.82 |
# | PURPLE CRYSTAL DROP EARRINGS           | $8.76 |
# | AMBER CRYSTAL DROP EARRINGS            | $8.76 |
# | GLASS BEAD HOOP EARRINGS MONTANA       | $8.76 |
# | RED PURSE WITH PINK HEART              | $8.75 |
# | SET 10 CARDS WISHING TREE 17116        | $8.73 |
# | SET 10 CARDS RUDOLPHS NOSE 17097       | $8.73 |
# | RED STONE/CRYSTAL EARRINGS             | $8.70 |
# | TURQUOISE BERTIE GLASS BEAD CHARM      | $8.65 |
# | M/COLOUR POM-POM CURTAIN               | $8.50 |
# | COUNTRY COTTAGE  DOORSTOP GREEN        | $8.47 |
# | OCEAN SCENT CANDLE JEWELLED DRAWER     | $8.47 |
# | HEART SHAPED MIRROR                    | $8.45 |
# | OPULENT VELVET SET/3 CANDLES           | $8.42 |
# | 50CM METAL STRING WITH  7 CLIPS        | $8.42 |
# | Dr. Jam's Arouzer Stress Ball          | $8.34 |
# | SET 10 CARDS CHRISTMAS HOLLY  17259    | $8.32 |
# | SET 10 MINICARDS CUTE SNOWMAN 17071    | $8.30 |
# | GLITTER CHRISTMAS HEART                | $8.27 |
# | PARTY TIME DESIGN FLANNEL              | $8.18 |
# | T-LIGHT HOLDER SILVER SAUCER           | $8.15 |
# | GOLD MINI TAPE MEASURE                 | $8.15 |
# | FRESHWATER PEARL BRACELET GOLD         | $7.65 |
# | BLUE CLIMBING HYDRANGA ART FLOWER      | $7.50 |
# | BEADED CRYSTAL HEART GREEN ON STICK    | $7.50 |
# | RUBY GLASS NECKLACE 42"                | $7.50 |
# | PINK CHERRY BLOSSOM CUP & SAUCER       | $7.50 |
# | EIGHT PIECE CREEPY CRAWLIE SET         | $7.50 |
# | ROSE FLOWER CANDLE+INCENSE 16X16CM     | $7.50 |
# | BAROQUE BUTTERFLY EARRINGS BLACK       | $7.50 |
# | ORANGE FLOWER MUG                      | $7.50 |
# | SET 10 CARDS FILIGREE BAUBLE 16961     | $7.47 |
# | SET 10 CARD SNOWMAN 16965              | $7.47 |
# | SET 10 CARDS PRINTED GRAPHIC 17219     | $7.47 |
# | SET 10 CARDS WORLD CHILDREN 17067      | $7.47 |
# | PINK STOCKING CHRISTMAS DECORATION     | $7.47 |
# | HARDMAN MUG 3 ASSORTED                 | $7.46 |
# | PINK LEAVES AND BEADS PHONE CHARM      | $7.43 |
# | JARDIN ETCHED GLASS BUTTER DISH        | $7.25 |
# | PURPLE ANEMONE ARTIFICIAL FLOWER       | $6.76 |
# | 4 GOLD FLOCK CHRISTMAS BALLS           | $6.72 |
# | WHITE DOVE HONEYCOMB PAPER GARLAND     | $6.72 |
# | ACRYLIC JEWEL ICICLE, PINK             | $6.65 |
# | SET/6 FRUIT SALAD PAPER CUPS           | $6.64 |
# | MULTI HEARTS  STICKERS                 | $6.64 |
# | SET 10 MINI SANTA & SNOWMAN  17087     | $6.64 |
# | ASSORTED TUTTI FRUTTI BRACELET         | $6.64 |
# | MULTICOLOUR POLKADOT PLATE             | $6.63 |
# | BLUE/YELLOW CERAMIC CANDLE HOLDER      | $6.60 |
# | LARGE BLACK DIAMANTE HAIRSLIDE         | $6.60 |
# | WHITE/PINK CHICK EASTER DECORATION     | $6.58 |
# | PAINTED PINK RABBIT                    | $6.58 |
# | AMBER BERTIE MOBILE PHONE CHARM        | $6.58 |
# | SET/6 COLLAGE PAPER PLATES             | $6.58 |
# | RETRO PLASTIC POLKA TRAY               | $6.55 |
# | PENS ASSORTED FUNKY JEWELED            | $6.55 |
# | ASSORTED FARMYARD ANIMALS IN BUCKET    | $6.52 |
# | EAU DE NILE JEWELLED T-LIGHT HOLDER    | $6.52 |
# | ASSORTED COLOUR SILK GLASSES CASE      | $6.30 |
# | LETTER "N" BLING KEY RING              | $6.25 |
# | TURQUOISE CHRISTMAS TREE               | $6.25 |
# | CAROUSEL PONIES BABY BIB               | $6.25 |
# | POCKET MIRROR "GLAMOROUS"              | $6.25 |
# | SET 10 CARDS CHRISTMAS ROBIN 17095     | $6.24 |
# | BLUE/NAT SHELL NECKLACE W PENDANT      | $5.95 |
# | FIRE POLISHED GLASS NECKL GOLD         | $5.95 |
# | ST GEORGE SET OF 10 PARTY LIGHTS       | $5.90 |
# | GOLD M.O.P. ORBIT NECKLACE             | $5.90 |
# | WHITE CHRISTMAS TREE 60CM              | $5.90 |
# | MAXWELL 2 TONE BLUE 60 PAGE PHOTO A    | $5.85 |
# | BLUE/YELLOW FLOWER DESIGN BIG MUG      | $5.85 |
# | GREEN/BLUE FLOWER DESIGN BIG MUG       | $5.85 |
# | SET 10 CARDS SWIRLY XMAS TREE 17104    | $5.82 |
# | SET 10 CARDS ROBIN WATERPUMP  17096    | $5.82 |
# | PURPLE FINE BEAD NECKLACE W TASSEL     | $5.82 |
# | SET 10 CARD CHRISTMAS STAMPS 16963     | $5.82 |
# | GREEN CRYSTAL DROP EARRINGS            | $5.80 |
# | BROWN VINTAGE VICTORIAN EARRINGS       | $5.80 |
# | MIRRORED WALL ART SNOWFLAKES           | $5.79 |
# | SET 10 CARDS HANGING BAUBLES 17080     | $5.48 |
# | SET OF 3 PINK FLYING DUCKS             | $5.45 |
# | MUMMY MOUSE RED GINGHAM RIBBON         | $5.45 |
# | POLYESTER FILLER PAD 60x40cm           | $5.10 |
# | NEW ENGLAND MUG W GIFT BOX             | $5.10 |
# | GREEN PENDANT SHELL NECKLACE           | $5.09 |
# | PINK ALLIUM  ARTIFICIAL FLOWER         | $5.07 |
# | ORIGAMI VANILLA INCENSE CONES          | $5.01 |
# | LETTER SHAPE PENCIL SHARPENER          | $5.00 |
# | ORANGE/FUSCHIA STONES NECKLACE         | $4.98 |
# | SET 10 CARDS DAVID'S MADONNA 17074     | $4.98 |
# | SET 10 CARDS DECK THE HALLS 16960      | $4.98 |
# | PURPLE LEAVES AND BEADS PHONE CHAR     | $4.97 |
# | ACRYLIC HANGING JEWEL,BLUE             | $4.97 |
# | GREEN LEAVES AND BEADS PHONE CHARM     | $4.97 |
# | BLOSSOM IMAGES SCRAP BOOK SET          | $4.95 |
# | VINTAGE BEAD PINK JEWEL STAND          | $4.95 |
# | LILY BROOCH WHITE/SILVER COLOUR        | $4.95 |
# | WISE MAN STAR SHAPE EGG PAN            | $4.95 |
# | PINK METAL SWINGING BUNNY              | $4.95 |
# | ASSORTED CIRCULAR MOBILE               | $4.95 |
# | GLITTER CHRISTMAS TREE                 | $4.92 |
# | LARGE HEART FLOWERS HOOK               | $4.92 |
# | PINK BEADS+HAND PHONE CHARM            | $4.92 |
# | PAINTED YELLOW WOODEN DAISY            | $4.92 |
# | COLUMBIAN  CUBE CANDLE                 | $4.92 |
# | RED DAISY POCKET BOOK                  | $4.89 |
# | 12 PENCILS TALL TUBE POSY              | $4.89 |
# | BLUE NEW BAROQUE FLOCK CANDLESTICK     | $4.65 |
# | EASTER BUNNY WITH BASKET ON BACK       | $4.38 |
# | BLUE PADDED SOFT MOBILE                | $4.25 |
# | FRYING PAN RED POLKADOT                | $4.25 |
# | CAKE STAND LACE WHITE                  | $4.25 |
# | ENAMEL BLUE RIM TEA CONTAINER          | $4.20 |
# | GOLD COSMETIC BAG PINK STAR            | $4.20 |
# | LIGHT DECORATION BATTERY OPERATED      | $4.20 |
# |  I LOVE LONDON MINI RUCKSACK           | $4.15 |
# | BLUE LEAVES AND BEADS PHONE CHARM      | $3.76 |
# | ROBOT MUG IN DISPLAY BOX               | $3.75 |
# | LETTER "P" BLING KEY RING              | $3.75 |
# | RETRO PLASTIC 70'S TRAY                | $3.75 |
# | GIFT BAG BIRTHDAY                      | $3.75 |
# | BAROQUE BUTTERFLY EARRINGS MONTANA     | $3.73 |
# | BAROQUE BUTTERFLY EARRINGS RED         | $3.73 |
# | WHITE ANEMONE ARTIFICIAL FLOWER        | $3.38 |
# | PINK BERTIE MOBILE PHONE CHARM         | $3.36 |
# | GARDENERS KNEELING PAD                 | $3.36 |
# | KEEP OUT GIRLS DOOR HANGER             | $3.36 |
# | WATERING CAN SINGLE HOOK PISTACHIO     | $3.36 |
# | SET 10 CARDS CHRISTMAS BAUBLE 16954    | $3.33 |
# | RED RETROSPOT TAPE                     | $3.32 |
# | BLUE DROP EARRINGS W BEAD CLUSTER      | $3.32 |
# | PINK FLUFFY CHRISTMAS DECORATION       | $3.26 |
# | ASS COLOUR GLOWING TIARAS              | $3.26 |
# | BLUE FELT HANGING HEART WITH FLOWER    | $3.26 |
# | SET/6 GREEN SPRING PAPER CUPS          | $3.26 |
# | SMALL STRIPES CHOCOLATE GIFT BAG       | $3.26 |
# | SET 10 CARDS SNOWY ROBIN 17099         | $2.91 |
# | SET 10 CARDS 3 WISE MEN 17107          | $2.91 |
# | SET 10 CARDS TRIANGLE ICONS  17220     | $2.91 |
# | NECKLACE+BRACELET SET PINK DAISY       | $2.55 |
# | PINK FEATHER CHRISTMAS DECORATION      | $2.51 |
# | BIRD BOX CHRISTMAS TREE DECORATION     | $2.51 |
# | LETTER "R" BLING KEY RING              | $2.50 |
# | PURPLE/TURQ FLOWERS HANDBAG            | $2.50 |
# | LETTER "V" BLING KEY RING              | $2.50 |
# | TINY CRYSTAL BRACELET RED              | $2.48 |
# | DOLPHIN WINDMILL                       | $2.12 |
# | TEA TIME BREAKFAST BASKET              | $2.10 |
# | GOLD COSMETICS BAG WITH BUTTERFLY      | $2.10 |
# | SCALLOP SHELL SOAP DISH                | $2.10 |
# | PINK DOLLY HAIR CLIPS                  | $2.10 |
# | SET/6 IVORY BIRD T-LIGHT CANDLES       | $2.10 |
# | ACRYLIC JEWEL SNOWFLAKE, PINK          | $2.10 |
# | YELLOW/PINK FLOWER DESIGN BIG MUG      | $1.95 |
# | EASTER CRAFT IVY WREATH WITH CHICK     | $1.95 |
# | SET OF THREE VINTAGE GIFT WRAPS        | $1.95 |
# | PINK/GREEN FLOWER DESIGN BIG MUG       | $1.95 |
# | PINK POLKADOT KIDS BAG                 | $1.95 |
# | RAIN PONCHO                            | $1.66 |
# | BLUE CRYSTAL BOOT PHONE CHARM          | $1.66 |
# | CROCHET LILAC/RED BEAR KEYRING         | $1.65 |
# | 3 BIRDS CANVAS SCREEN                  | $1.65 |
# | FLOWER SHOP DESIGN MUG                 | $1.65 |
# | PARTY INVITES SPACEMAN                 | $1.63 |
# | SET/6 COLLAGE PAPER CUPS               | $1.63 |
# | ENGLISH ROSE NOTEBOOK A6 SIZE          | $1.46 |
# | BLACKCHRISTMAS TREE 30CM               | $1.25 |
# | BLING KEY RING STAND                   | $1.25 |
# | ORANGE FELT VASE + FLOWERS             | $1.25 |
# | FUNKY MONKEY MUG                       | $1.25 |
# | SET 36 COLOURING PENCILS DOILEY        | $1.25 |
# | PACK 4 FLOWER/BUTTERFLY PATCHES        | $1.25 |
# | LETTER "Y" BLING KEY RING              | $1.25 |
# | ETCHED GLASS STAR TREE DECORATION      | $1.25 |
# | LETTER "B" BLING KEY RING              | $1.25 |
# | WIRE FLOWER T-LIGHT HOLDER             | $1.25 |
# | DUSTY PINK CHRISTMAS TREE 30CM         | $1.25 |
# | S/4 ICON COASTER,ELVIS LIVES           | $1.25 |
# | DECORATION SITTING BUNNY               | $1.21 |

# %% [markdown]
# #### There is a long product tail. Let's see how many products we have under $1,000 in annual revenue

# %%
# Total number of products
total_products = len(product_revenue)
formatted_total_products = "{:,}".format(total_products)
print(f"Total Number of Products: {formatted_total_products}")

# Count of products with less than $1000 in annual revenue
low_revenue_products_count = (product_revenue < 1000).sum()
formatted_low_revenue_count = "{:,}".format(low_revenue_products_count)
print(f"Products with less than $1000 in Annual Revenue: {formatted_low_revenue_count}")
# Out:
# Total Number of Products: 3,633
# Products with less than $1000 in Annual Revenue: 2,314

# %% [markdown]
# #### Further analysis needs to be done on this tail. Some general recommendations for a long product tail is:
#
# When dealing with products that have low annual sales or form a long tail in your online sales data, there are several creative approaches you can consider to address them:
#
# #### Bundle or package them:
# - Combine low-selling products into bundles or packages to create more appealing offerings. This can help increase their perceived value and attract customers who may be interested in multiple items.
#
# #### Promotions and discounts:
# - Offer special promotions, discounts, or limited-time offers specifically for the low-selling products. This can generate interest and encourage customers to give them a try.
#
# #### Cross-selling and upselling:
# - Promote the low-selling products as complementary items to more popular or higher-margin products. Cross-selling and upselling techniques can help increase the visibility and sales of these products.
#
# #### Target niche markets:
# - Identify niche markets or specific customer segments that may have a higher interest in the low-selling products. Tailor your marketing efforts to reach those audiences through targeted advertising or partnerships.
#
# #### Enhance product descriptions and visuals:
# - Improve the product descriptions, images, and other visuals to make the low-selling products more appealing and engaging. Highlight unique features, benefits, or potential use cases that might resonate with customers.
#
# #### Collaborate with influencers or affiliates:
# - Partner with influencers or affiliates in your industry who can promote the low-selling products to their audience. Their endorsement or recommendation can help generate awareness and boost sales.
#
# #### Explore new sales channels:
# - Consider expanding your sales channels to reach a broader customer base. Explore options such as online marketplaces, social media platforms, or niche-specific platforms where your low-selling products might find a more receptive audience.
#
# #### Customer feedback and reviews:
# - Encourage customers to provide feedback and reviews for the low-selling products. Positive reviews can increase credibility and attract new customers. Address any negative feedback constructively to improve the products and customer satisfaction.
#
# #### Product positioning or rebranding:
# - Evaluate the positioning and branding of the low-selling products. It might be necessary to reposition or rebrand them to better align with customer needs, trends, or preferences. This can help create a fresh perspective and increase their appeal.
#
# #### Product improvements or variations:
# - Assess if there are any improvements or variations you can make to the low-selling products based on customer feedback or market trends. This could involve tweaking features, introducing new sizes or colors, or enhancing functionality to better meet customer demands.
#
# It's essential to track the results of any initiatives you implement and adjust your strategies accordingly. The goal is to find the most effective approaches for addressing low-selling products and maximizing their sales potential, or eliminate them altogether.

# %% [markdown]
# Identify top-selling products and categories based on revenue and quantity sold

# %%
# Top 10 products by quantity sold
top_10_products_by_quantity = data.groupby('Description')['Quantity'].sum().sort_values(ascending=False).head(10)
print("Top 10 Products by Quantity Sold:\n", top_10_products_by_quantity)
# Out:
# Top 10 Products by Quantity Sold:
#  Description
# MEDIUM CERAMIC TOP STORAGE JAR        77826
# JUMBO BAG RED RETROSPOT               47369
# WHITE HANGING HEART T-LIGHT HOLDER    37113
# ASSORTED COLOUR BIRD ORNAMENT         35131
# RABBIT NIGHT LIGHT                    26477
# VICTORIAN GLASS HANGING T-LIGHT       21202
# JUMBO BAG PINK POLKADOT               21006
# RED  HARMONICA IN BOX                 20775
# LUNCH BAG RED RETROSPOT               18956
# PARTY BUNTING                         18159
# Name: Quantity, dtype: int64

# %% [markdown]
# Looked up some code snippets to show this in an easy to read table

# %%
# Top 10 products by quantity sold
top_10_products_by_quantity = data.groupby('Description')['Quantity'].sum().sort_values(ascending=False).head(10)
print("\nTop 10 Products by Quantity Sold:")
print("| Rank | Description                           | Quantity    | Revenue      |")
print("|------|---------------------------------------|-------------|--------------|")
for rank, (description, quantity) in enumerate(top_10_products_by_quantity.iteritems(), start=1):
    revenue = product_revenue[description]
    formatted_revenue = "${:,.2f}".format(revenue)
    print(f"| {rank:<4} | {description:<38} | {quantity:<11} | {formatted_revenue:<12} |")
# Out:
# Top 10 Products by Quantity Sold:
# | Rank | Description                           | Quantity    | Revenue      |
# |------|---------------------------------------|-------------|--------------|
# | 1    | MEDIUM CERAMIC TOP STORAGE JAR         | 77826       | $81,448.21   |
# | 2    | JUMBO BAG RED RETROSPOT                | 47369       | $92,113.15   |
# | 3    | WHITE HANGING HEART T-LIGHT HOLDER     | 37113       | $104,085.75  |
# | 4    | ASSORTED COLOUR BIRD ORNAMENT          | 35131       | $56,932.19   |
# | 5    | RABBIT NIGHT LIGHT                     | 26477       | $57,321.97   |
# | 6    | VICTORIAN GLASS HANGING T-LIGHT        | 21202       | $29,402.51   |
# | 7    | JUMBO BAG PINK POLKADOT                | 21006       | $41,509.92   |
# | 8    | RED  HARMONICA IN BOX                  | 20775       | $25,106.60   |
# | 9    | LUNCH BAG RED RETROSPOT                | 18956       | $34,975.66   |
# | 10   | PARTY BUNTING                          | 18159       | $98,585.85   |

# %%
# Define colorblind-friendly color palette
palette = ['#4C72B0', '#DD8452', '#55A868', '#C44E52', '#8172B2', '#937860', '#DA8BC3', '#8C8C8C', '#CCB974', '#64B5CD']

# Revenue by product (limited to top 10 products)
product_revenue = data.groupby('Description')['Revenue'].sum().sort_values(ascending=False)[:10]

# Create bar chart with colorblind-friendly colors
fig, ax = plt.subplots(figsize=(8, 6))
ax.bar(product_revenue.index, product_revenue.values, color=palette)
ax.set_xticklabels([])  # remove x-axis labels
ax.set_xlabel('')
ax.set_ylabel('Revenue ($)')
ax.set_title('Revenue by Product (Top 10)')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Format y-axis labels with dollar signs
def currency(x, pos):
    """The two args are the value and tick position"""
    return "${:,.0f}".format(x)
ax.yaxis.set_major_formatter(plt.FuncFormatter(currency))

# Create legend
handles = [plt.Rectangle((0,0),1,1, color=palette[i]) for i in range(len(product_revenue))]
ax.legend(handles, product_revenue.index, loc='upper right', framealpha=0.9)

# Save to file in the Downloads folder
save_path = os.path.join(os.path.expanduser('~'), 'Downloads', 'revenue_by_product (Top 10)_bar_colored.png')
plt.savefig(save_path, bbox_inches='tight')

# Show figure
plt.show()

# %% [markdown]
# ---------

# %% [markdown]
# <a id="Pricing-Profitability-Analysis"></a>
# ## 2. Pricing & Profitability Analysis

# %% [markdown]
# ### Profitability Analysis
# #### We are unable to preform a profitibility analysis, as we do not have the product cost, we only have the `UnitPrice` & `Revenue`. Here are some potential insights that can be derived from this kind of analysis:

# %% [markdown]
# #### Overall Profitability:
# - This is the most direct insight. By comparing revenue to expenses, you can understand if your online store is currently profitable, and how profitability may have changed over time.
# #### Product Profitability:
# - Profitability analysis often includes a breakdown by product or product category. This can show which items are the most profitable and which are the least. You might find that a small subset of your products are responsible for a large portion of your profit. We can focus on driving sales by using those products for suggsted addons.
# #### Customer Profitability:
# - Similar to product profitability, you can also analyze profitability by customer. This might involve segmenting customers by characteristics like location, purchase frequency, or average order size.
# #### Marketing ROI:
# - If you're spending money on marketing and advertising, profitability analysis can help determine the return on investment (ROI) for these activities. For example, you might find that certain marketing channels drive sales of more profitable products vs others.
# #### Pricing Strategy:
# - If your analysis shows low profitability despite high sales volumes, it might indicate a need to revisit your pricing strategy. Alternatively, if volumes are low but profitability is high, it could suggest that there's room to experiment with lower prices.
# #### Growth Opportunities:
# - Profitability analysis can also help identify opportunities for growth. For example, if certain products or customer segments are particularly profitable, you might look for ways to sell more of these products or attract more of these customers.
# #### Cash Flow Management:
# - Profitability doesn't necessarily equate to positive cash flow, but it drives positive cashflow. Understanding the timing of income and expenses can help manage cash flow, which is crucial for any business.

# %% [markdown]
# ----

# %% [markdown]
# <a id="Customer-Segmentation"></a>
# ## 3. Customer Segmentation
#
# Resource https://www.youtube.com/watch?v=i-HNJZeOOMY and https://www.youtube.com/watch?v=WvmFjuGxneI

# %% [markdown]
# We going to use Customer segmentation using RFM (Recency, Frequency, Monetary) analysis is a method of dividing customers into groups based on their purchase behavior. It's a relatively simple, yet powerful, way of understanding different types of customers and their value to the business.
#
# #### Recency (R):
# - This is how recent the customer's last purchase was. Customers who have purchased more recently are often more engaged and more likely to make future purchases.
#
# #### Frequency (F):
# - This is how often the customer makes a purchase. Customers who purchase frequently are more engaged and valuable than those who purchase occasionally.
#
# #### Monetary (M):
# - This is how much the customer spends. Customers who spend more are, of course, more valuable to the business.

# %% [markdown]
# #### Calculate total purchase:
# - Create a new column 'TotalPurchase' which is the product of 'Quantity' and 'UnitPrice'.

# %%
# Identify the latest date in the data plus one day. This will be used to calculate recency of purchase.
snapshot_date = data['InvoiceDate'].max() + dt.timedelta(days=1)

# Calculate recency in terms of days between the snapshot date and the latest invoice date per customer
data_recency = data.groupby('CustomerID').agg({
    'InvoiceDate': lambda x: (snapshot_date - x.max()).days
})

# Calculate frequency by counting the number of invoices per customer
data_frequency = data.groupby('CustomerID').agg({
    'InvoiceNo': 'count'
})

# Calculate monetary by summing up the 'TotalPurchase' per customer
data_monetary = data.groupby('CustomerID').agg({
    'Revenue': 'sum'
})

# Combine recency, frequency, and monetary dataframes together
# This results in an RFM table where each customer has a recency, frequency, and monetary value
data_rfm = data_recency.join(data_frequency).join(data_monetary)

# Include the 'CustomerID' column from the original dataset
data_rfm['CustomerID'] = data_rfm.index

# Update the column names of the data_rfm DataFrame
data_rfm.columns = ['Recency', 'Frequency', 'Monetary', 'CustomerID']

# %%
# Display the first 5 rows of the RFM table
print(data_rfm.head())
# Out:
#             Recency  Frequency  Monetary  CustomerID
# CustomerID
# 12346.0         317          1  77183.60     12346.0
# 12347.0          31        133   3598.64     12347.0
# 12348.0          67          7    754.00     12348.0
# 12349.0          10         63   1368.75     12349.0
# 12350.0         302         13    255.30     12350.0

# %%
# Display the statistical summary of the RFM table
print(data_rfm.describe())
# Out:
#            Recency      Frequency      Monetary    CustomerID
# count  4263.000000    4263.000000  4.263000e+03  4.263000e+03
# mean     91.723434      93.390335  2.043668e+03  2.361041e+06
# std      98.791186    1641.927957  2.286063e+04  1.531572e+08
# min       1.000000       1.000000  1.250000e+00  1.234600e+04
# 25%      16.000000      13.000000  2.536350e+02  1.381800e+04
# 50%      50.000000      31.000000  5.593300e+02  1.530000e+04
# 75%     146.000000      75.500000  1.368075e+03  1.678050e+04
# max     365.000000  106713.000000  1.407735e+06  9.999900e+09

# %%
# Calculate z-scores for each column in data_rfm
z_scores = (data_rfm - data_rfm.mean()) / data_rfm.std()

# Define a threshold for outlier detection (e.g., z-score > 3 or z-score < -3)
threshold = 3

# Create a boolean mask to identify outliers
outlier_mask = np.abs(z_scores) > threshold

# Remove outliers from data_rfm
data_rfm_no_outliers = data_rfm[~outlier_mask.any(axis=1)]

# %%
# Initialize the Scaler
scaler = MinMaxScaler()

# Fit and transform the RFM data
data_rfm_normalized = scaler.fit_transform(data_rfm)

# Convert the normalized data into a DataFrame
data_rfm_normalized = pd.DataFrame(data_rfm_normalized, index=data_rfm.index, columns=data_rfm.columns)

# %%
# Fit KMeans and calculate SSE for each k
sse = {}
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=1)
    kmeans.fit(data_rfm_normalized)
    sse[k] = kmeans.inertia_ # sum of squared distances to closest cluster center

# Plot Elbow Method to find best k
plt.title('The Elbow Method')
plt.xlabel('k'); plt.ylabel('SSE')
sns.pointplot(x=list(sse.keys()), y=list(sse.values()))
plt.show()

# %% [markdown]
# I will use 3 as my number of clusters

# %%
from sklearn.cluster import KMeans

# Choose the number of clusters based of above elbow
k = 3

# Initialize KMeans
kmeans = KMeans(n_clusters=k, random_state=1)

# Fit the normalized data
kmeans.fit(data_rfm_normalized)

# Assign the clusters to datamart
data_rfm['K_Cluster'] = kmeans.labels_

# %%
# Display the first 5 rows of the RFM table with K_Cluster
print(data_rfm.head())
# Out:
#             Recency  Frequency  Monetary  CustomerID  K_Cluster
# CustomerID
# 12346.0         317          1  77183.60     12346.0          2
# 12347.0          31        133   3598.64     12347.0          0
# 12348.0          67          7    754.00     12348.0          0
# 12349.0          10         63   1368.75     12349.0          0
# 12350.0         302         13    255.30     12350.0          2

# %% [markdown]
# Let's create a dictonary to rename the clusters

# %%
# Create a mapping from the original cluster labels to the new ones
cluster_name_mapping = {0: 'Lapsed Customers', 1: 'At Risk', 2: 'Best Customers'}

# Map the labels
data_rfm['K_Cluster'] = data_rfm['K_Cluster'].map(cluster_name_mapping)

# %%
# Count the number of customers in each cluster
print(data_rfm['K_Cluster'].value_counts())
# Out:
# Lapsed Customers    2820
# At Risk              812
# Best Customers       631
# Name: K_Cluster, dtype: int64

# %%
# Calculate average RFM values and size for each cluster
print(data_rfm.groupby('K_Cluster').agg({
    'Recency': 'mean',
    'Frequency': 'mean',
    'Monetary': ['mean', 'count']
}).round(1))
# Out:
#                  Recency Frequency Monetary
#                     mean      mean     mean count
# K_Cluster
# At Risk            151.5      31.5    669.5   812
# Best Customers     287.7      19.5    559.8   631
# Lapsed Customers    30.7     127.8   2771.4  2820

# %%
# Assuming you have a DataFrame called 'cluster_data' that contains the cluster labels for each customer
cluster_counts = data_rfm['K_Cluster'].value_counts()

# Plotting the bar chart
plt.figure(figsize=(8, 6))  # Adjust the figure size as needed
plt.barh(cluster_counts.index, cluster_counts.values, color='skyblue')  # Using barh for horizontal bars

plt.xlabel('Number of Customers')  # Reversing x-axis label
plt.ylabel('Cluster')  # Reversing y-axis label
plt.title('Number of Customers in Each Cluster')

plt.yticks(cluster_counts.index)  # Ensure all clusters are displayed on the y-axis
plt.tight_layout()  # Improves spacing between plot elements

# Save figure to file in the Downloads folder
save_path = os.path.join(os.path.expanduser('~'), 'Downloads', 'Customer Segmentation.png')
plt.savefig(save_path, bbox_inches='tight')

plt.show()

# %%
# Define the desired order of clusters
cluster_order = ['Best Customers', 'At Risk', 'Lapsed Users']

# Filter the DataFrame to retrieve the customer(s) with the desired cluster tag(s)
customer_list = data_rfm[data_rfm['K_Cluster'].isin(cluster_order)]

# Sort the customer list by cluster in the desired order
customer_list_sorted = customer_list.sort_values(by=['K_Cluster'], key=lambda x: x.map({k: v for v, k in enumerate(cluster_order)}))

# Export the sorted customer list to a CSV file in the Downloads folder
download_path = "Downloads/customer_list_RMF.csv"  # Modify the path to match your system
customer_list_sorted.to_csv(download_path, index=False)

# %%
dataRFM = pd.read_csv('downloads/customer_list_RMF.csv')

# %%
dataRFM.head()
# Out:
#    Recency  Frequency  Monetary  CustomerID       K_Cluster
# 0      317          1  77183.60     12346.0  Best Customers
# 1      258         18    323.30     14633.0  Best Customers
# 2      253          1     25.50     17102.0  Best Customers
# 3      314          8    244.20     17094.0  Best Customers
# 4      233        132   1052.41     14669.0  Best Customers

# %%
dataRFM.tail()
# Out:
#       Recency  Frequency  Monetary  CustomerID K_Cluster
# 1438      107         94   1477.89     15002.0   At Risk
# 1439      139        124   1124.90     15004.0   At Risk
# 1440      151         12    156.91     15007.0   At Risk
# 1441      119         13    224.52     15254.0   At Risk
# 1442      118          5     79.65     18282.0   At Risk

# %% [markdown]
# #### Best Customers (High Monetary, High Frequency, Low Recency):
# - These are your most valuable customers. They've made purchases recently, frequently, and they're high spenders.
#
# Action: Aim to keep these customers satisfied and engaged. Send them personalized emails thanking them for their patronage. You could also offer them exclusive deals or access to new products before everyone else. Create a loyalty program to reward them for their continued patronage.
#
# #### At Risk (Medium Monetary, Medium Frequency, Medium Recency):
# - These customers used to shop frequently and spend a decent amount but haven't made a purchase in a while.
#
# Action: You should aim to re-engage these customers as quickly as possible. Send them personalized offers based on their previous purchases, or reminders about items they may have left in their cart. Consider offering them a special discount to entice them to make a purchase.
#
# #### Lapsed Customers (High Recency, Low Frequency, Low Monetary):
# - These are customers who haven't purchased in a long time. They've made few purchases and those purchases were of lower value.
#
# Action: Re-engaging lapsed customers can be difficult and costly. However, you can try sending them surveys to understand why they stopped buying. If they had a bad experience, you could try to rectify it. Offering them a re-engagement discount might also work. But remember, it's often more cost-effective to retain existing customers than to re-engage lapsed ones.

# %% [markdown]
# -----

# %% [markdown]
# <a id="Geographic-Analysis"></a>
# ## 4. Geographic Analysis

# %% [markdown]
# #### Sales performance by country

# %%
# Group the data by 'Country', calculate the sum of 'Revenue' for each country and sort the values in descending order
sales_by_country = data.groupby('Country')['Revenue'].sum().sort_values(ascending=False)

# Display the sales performance by country
print(sales_by_country)
# Out:
# Country
# United Kingdom          7379406.28
# EIRE                     246688.77
# Netherlands              233157.89
# Germany                  174848.42
# France                   162695.86
# Australia                122624.01
# Spain                     50379.73
# Switzerland               46669.57
# Japan                     31914.79
# Belgium                   29740.93
# Norway                    27081.46
# Portugal                  25839.60
# Sweden                    22709.55
# Singapore                 19699.21
# Channel Islands           18065.57
# Denmark                   16791.90
# Finland                   15389.00
# Hong Kong                 14536.36
# Italy                     13741.95
# Cyprus                    12153.38
# Austria                    7175.58
# Israel                     6996.52
# Poland                     6311.31
# Unspecified                3930.08
# Greece                     3712.99
# Iceland                    3598.64
# Canada                     2560.20
# USA                        2208.63
# Malta                      1997.99
# Lebanon                    1670.48
# Lithuania                  1661.06
# United Arab Emirates       1598.00
# Brazil                     1123.20
# European Community         1053.65
# RSA                         981.97
# Bahrain                     754.14
# Czech Republic              546.66
# Saudi Arabia                140.88
# Name: Revenue, dtype: float64

# %%
# Group the data by 'Country', calculate the sum of 'Revenue' for each country, and sort the values in descending order
sales_by_country = data.groupby('Country')['Revenue'].sum().sort_values(ascending=False)

# Select the top 5 countries
top_5_countries = sales_by_country.head(5)

# Calculate the percentage for each country
total_sales = top_5_countries.sum()
percentages = (top_5_countries / total_sales) * 100

# Create a bar plot
fig, ax = plt.subplots()
bars = ax.bar(top_5_countries.index, top_5_countries)

# Add the percentage labels to the plot
for i, value in enumerate(top_5_countries):
    ax.text(i, value, f'{percentages[i]:.1f}%', ha='center', va='bottom')

# Format the y-axis tick labels as dollar figures with thousands separators
formatter = ticker.StrMethodFormatter('${x:,.0f}')
ax.yaxis.set_major_formatter(formatter)

# Set the plot title and labels
ax.set_title('Top 5 Countries by Sales')
ax.set_xlabel('Country')
ax.set_ylabel('Total Sales')

# Set the plot style
plt.style.use('ggplot')

# Customize the colors of the bars
colors = ['#4286f4', '#f45642', '#42f487', '#f4d942', '#8242f4']
for i, bar in enumerate(bars):
    bar.set_color(colors[i])


# Remove the spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)    

# Add grid lines to the plot
ax.grid(axis='y', linestyle='--', alpha=0.5)

# Save figure to file in the Downloads folder
save_path = os.path.join(os.path.expanduser('~'), 'Downloads', 'Top_5_Countries_by_Sales.png')
plt.savefig(save_path, bbox_inches='tight', dpi=300)

# Display the plot
plt.show()

# %% [markdown]
# ------

# %% [markdown]
# <a id="Time-Based-Analysis"></a>
# ## 5. Time-Based Analysis

# %% [markdown]
# #### Determine Peak Shopping Hours and Days

# %%
# Extract hour and day of week from 'InvoiceDate'
data['Hour'] = data['InvoiceDate'].dt.hour
data['DayOfWeek'] = data['InvoiceDate'].dt.dayofweek

# Group by 'Hour' and 'DayOfWeek' and sum 'Quantity'
peak_hours_days = data.groupby(['DayOfWeek', 'Hour'])['Quantity'].sum()

# Display the peak shopping hours and days
print(peak_hours_days)
# Out:
# DayOfWeek  Hour
# 0          7         249
#            8       16358
#            9       50365
#            10      69786
#            11      58560
#                    ...
# 6          12      50370
#            13      45470
#            14      34729
#            15      41811
#            16      13240
# Name: Quantity, Length: 74, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Reset index of the grouped data to make 'DayOfWeek' and 'Hour' into columns
peak_hours_days = peak_hours_days.reset_index()

# Pivot the data to get 'Hour' as columns, 'DayOfWeek' as rows, and 'Quantity' as values
pivot_df = peak_hours_days.pivot('DayOfWeek', 'Hour', 'Quantity')

# Create a heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(pivot_df, cmap='YlGnBu')

plt.title('Peak Shopping Hours and Days')
plt.xlabel('Hour of the Day')
plt.ylabel('Day of the Week')

# Days of the week from 0 to 6 represent Monday to Sunday
plt.yticks(ticks=[0, 1, 2, 3, 4, 5, 6], labels=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'], rotation=0)

# Save figure to file in the Downloads folder
save_path = os.path.join(os.path.expanduser('~'), 'Downloads', 'Peak Shopping Times.png')
plt.savefig(save_path, bbox_inches='tight')

plt.show()

# %% [markdown]
# #### The heatmap from the peak shopping hours and days analysis can provide a wealth of insights that can guide business decisions. Here are some potential insights and actions you can consider:

# %% [markdown]
# #### Identify Peak Shopping Times:
# - Your heatmap can clearly show when your customers are most active on your website.
#
# Action: Use this information to ensure your website is prepared for heavy traffic during these hours. This can improve the online shopping experience and potentially increase conversions.
#
# #### Identify Off-Peak Shopping Times:
# - The heatmap will also show when your website has the least traffic.
#
# Action: Schedule website maintenance or updates during these times to minimize the impact on customers. You might also consider time-specific promotions to encourage more activity during these quieter periods.
#
# #### Promotional Activities and Marketing:
# - Knowing when customers are most likely to be shopping can help inform your promotional activities and email marketing strategy.
#
# Action: Schedule email campaigns, social media posts, or push notifications to go out just before or during these peak times to engage customers while they're most active.
#
# #### Personalization:
# - If you can tie the peak times to specific user demographics (like location), you can offer a personalized user experience.
#
# Action: Personalize the shopping experience by featuring products during peak times that are popular in the customer's location or according to their previous browsing history.
#
# #### Customer Support:
# - If you provide live customer support, such as chat or phone support, peak shopping times can guide staffing decisions.
#
# Action: Ensure that enough customer service representatives are available during peak shopping times to handle inquiries, assist with purchases, and resolve issues promptly.
#
# #### Supply Chain Management:
# - Peaks in online activity can impact your inventory and fulfillment operations.
#
# Action: Coordinate with your supply chain to ensure that popular items remain in stock and that fulfillment operations are prepared to handle an increase in orders during peak times.
#
# #### Sales Forecasting:
# - Patterns of online shopping activity can help predict future sales and website traffic.
#
# Action: Use these patterns to anticipate periods of high demand, allowing you to optimize inventory, staffing, and marketing efforts. You can also use this information to manage server resources and prevent website downtime during peak shopping times.

# %% [markdown]
# -----

# %% [markdown]
# <a id="Inventory-Analysis"></a>
# ##  6. Inventory Analysis

# %%
# Calculate the turnover rate as total quantity sold divided by the number of unique invoices for each product
data['TurnoverRate'] = data.groupby('StockCode')['Quantity'].transform('sum') / data.groupby('StockCode')['InvoiceNo'].transform('nunique')

# %%
# Display the items with the highest turnover rates
print(data[['StockCode', 'TurnoverRate']].drop_duplicates().sort_values(by='TurnoverRate', ascending=False))
# Out:
#        StockCode  TurnoverRate
# 52771     47556B   1300.000000
# 61619      23166    334.017167
# 446973     23378    254.500000
# 446974     23376    147.000000
# 138639     22616    144.333333
# ...          ...           ...
# 287644     22016      1.000000
# 124191     90068      1.000000
# 285702     35650      1.000000
# 6142      90060F      1.000000
# 219409    82613a      1.000000
#
# [3547 rows x 2 columns]

# %%
# Display the items with the lowest turnover rates
print(data[['StockCode', 'TurnoverRate']].drop_duplicates().sort_values(by='TurnoverRate'))
# Out:
#        StockCode  TurnoverRate
# 12231     90060D      1.000000
# 10800      90132      1.000000
# 10801      90140      1.000000
# 140940    84743C      1.000000
# 137681    85049d      1.000000
# ...          ...           ...
# 138639     22616    144.333333
# 446974     23376    147.000000
# 446973     23378    254.500000
# 61619      23166    334.017167
# 52771     47556B   1300.000000
#
# [3547 rows x 2 columns]

# %%
# Classify items into 'A', 'B', or 'C' based on the quantile of turnover rate
data['ABC'] = pd.qcut(data['TurnoverRate'], q=[0, 0.2, 0.8, 1], labels=['C', 'B', 'A'])

# %%
# Display the classification results
print(data[['StockCode', 'ABC']].drop_duplicates())
# Out:
#        StockCode ABC
# 0         85123A   A
# 1          71053   B
# 2         84406B   B
# 3         84029G   B
# 4         84029E   B
# ...          ...  ..
# 503602     23562   C
# 504104     23561   A
# 507867     23609   C
# 509369    85179a   C
# 512588     23617   C
#
# [3547 rows x 2 columns]

# %%
# Plot the number of items in each category
sns.countplot(x='ABC', data=data, order=['A', 'B', 'C'])

plt.xlabel('ABC Category')
plt.ylabel('Number of Items')
plt.title('Number of Items in Each ABC Category')

plt.show()

# %%
# Relabel the x-axis categories as 'High Turnover', 'Moderate Turnover', and 'Low Turnover'
sns.countplot(x='ABC', data=data, order=['A', 'B', 'C'])
plt.xticks(ticks=[0, 1, 2], labels=['High Turnover(A)', 'Moderate Turnover(B)', 'Low Turnover(C)'])

plt.xlabel('')
plt.ylabel('Number of Items')
plt.title('Product Turnover Analysis')

# Save figure to file in the Downloads folder
save_path = os.path.join(os.path.expanduser('~'), 'Downloads', 'Product Turnover Analysis2.png')
plt.savefig(save_path, bbox_inches='tight')

plt.show()

# %% [markdown]
# #### The insights derived from inventory analysis can be used to make important business decisions and optimizations.

# %% [markdown]
# #### Optimize Stock Levels:
# - Identifying products with high turnover rates can help ensure that popular items remain in stock. At the same time, it can help identify slow-moving or overstocked items. This will help in maintaining an optimal inventory level, reducing carrying costs, and minimizing the risk of stockouts.
#
# Action: Increase order quantities and frequency for high turnover items ('A' items). For slow-moving or overstocked items ('C' items), consider decreasing order quantities, increasing promotion efforts, or even discontinuing the product if it's consistently not performing.
#
# #### Improve Forecasting:
# - The ABC classification can be used to improve sales forecasting. 'A' items are likely to contribute the most to future sales, while 'C' items will contribute the least.
#
# Action: Prioritize 'A' items in sales forecasts. Consider the sales patterns of 'A' items when forecasting overall sales and when making purchasing and restocking decisions with suppliers.
#
# #### Refine Marketing and Promotion:
# - Understanding which items are most popular can also inform marketing and promotional strategies.
#
# Action: Highlight 'A' items in marketing campaigns to attract customers. For 'C' items, consider targeted promotions to clear excess stock and improve turnover rates.
#
# #### Negotiate with Suppliers:
# - Having a clear understanding of your inventory turnover can also aid in negotiations with suppliers.
#
# Action: For 'A' items, negotiate better prices or delivery times due to the high volume of orders. For 'C' items, negotiate smaller order sizes or longer payment terms to reduce carrying costs.
#
# #### Inventory Management Policies:
# - The ABC classification can guide inventory management policies. 'A' items may require tighter control and more frequent review than 'B' or 'C' items.
#
# Action: Implement different inventory management policies for 'A', 'B', and 'C' items. For example, use a continuous review policy for 'A' items and a periodic review policy for 'B' and 'C' items.

# %% [markdown]
# -----

# %% [markdown]
# <a id="Customer-Retention-Analysis"></a>
# ## 7. Customer Retention Analysis

# %% [markdown]
# ### Customer Lifetime Value CLV
#
# Customer Lifetime Value (CLV) is the total worth to a business of a customer over the whole period of their relationship. It's an important metric as it costs less to keep existing customers than it does to acquire new ones, so increasing the value of your existing customers is key.

# %%
# Average Purchase Value
avg_purchase = data['Revenue'].sum() / data['InvoiceNo'].nunique()

# Number of Repeat Purchases
purchase_freq = data.groupby('CustomerID')['InvoiceNo'].nunique()
avg_repeat_purchases = purchase_freq.mean() - 1

# Average Customer Lifespan
# Assuming you have only one year of data, let's use 1 year as lifespan
avg_lifespan = 1  # in years

# CLV
clv = avg_purchase * avg_repeat_purchases * avg_lifespan

print('Estimated Customer Lifetime Value (CLV) is: $', round(clv, 2))
# Out:
# Estimated Customer Lifetime Value (CLV) is: $ 1577.05

# %%
# Calculate average purchase value per customer
avg_purchase_per_customer = data.groupby('CustomerID')['Revenue'].sum() / data.groupby('CustomerID')['InvoiceNo'].nunique()

# Calculate number of repeat purchases per customer
repeat_purchases_per_customer = data.groupby('CustomerID')['InvoiceNo'].nunique() - 1

# Assuming you have only one year of data, let's use 1 year as lifespan
lifespan_per_customer = 1  # in years

# CLV per customer
clv_per_customer = avg_purchase_per_customer * repeat_purchases_per_customer * lifespan_per_customer

# Convert to DataFrame for easier manipulation
clv_df = clv_per_customer.reset_index()
clv_df.columns = ['CustomerID', 'CLV']

# First, remove the customers with zero CLV
clv_df = clv_df[clv_df['CLV'] > 0]

# If you still have customers with identical CLV, 
# it's better to use cut function instead of qcut

# Define bin edges
bin_edges = [clv_df['CLV'].min(), clv_df['CLV'].quantile(0.25), clv_df['CLV'].quantile(0.75), clv_df['CLV'].max()]

# Define labels
labels=['Low', 'Medium', 'High']

# Use cut function to create segments
clv_df['CLV_Segment'] = pd.cut(clv_df['CLV'], bins=bin_edges, labels=labels, include_lowest=True)

clv_df.head()
# Out:
#     CustomerID          CLV CLV_Segment
# 1      12347.0  2998.866667        High
# 2      12348.0   502.666667      Medium
# 5      12352.0  1920.660000        High
# 9      12356.0  1389.440000      Medium
# 12     12359.0  4649.565000        High

# %%
# Count the number of customers in each segment
segment_counts = clv_df['CLV_Segment'].value_counts()

# Convert the series to a DataFrame and reset the index
segment_counts_df = segment_counts.reset_index()

# Rename the columns for clarity
segment_counts_df.columns = ['CLV_Segment', 'Number_of_Customers']

# %%
# Print the DataFrame
print(segment_counts_df)
# Out:
#   CLV_Segment  Number_of_Customers
# 0      Medium                 1358
# 1         Low                  679
# 2        High                  679

# %%
# Plot
plt.figure(figsize=(8,6))
sns.barplot(x=segment_counts.index, y=segment_counts.values, palette="Blues_d")
plt.title('CLV Customer Segments')
plt.xlabel('CLV Segments')
plt.ylabel('Number of Customers')
plt.show()

# Save figure to file in the Downloads folder
save_path = os.path.join(os.path.expanduser('~'), 'Downloads', 'CLV Customer Segments.png')
plt.savefig(save_path, bbox_inches='tight', dpi=300)

# %% [markdown]
# Our Customer Lifetime Value (CLV) analysis segmented our customer base into three groups: Low, Medium, and High CLV. The majority of our customers, totaling 1,358, fall into the Medium CLV category, regularly contributing to our revenue. However, we also have an equal distribution of Low and High CLV customers, each with 679 individuals.
#
# Low CLV customers are those who provide less revenue, perhaps due to infrequent buying or lower spending. Conversely, High CLV customers significantly contribute to our business due to regular, high-value purchases.
#
# This data gives us an opportunity to devise specific marketing strategies. For Medium CLV customers, we can focus on upselling and cross-selling. Retention efforts should be increased for High CLV customers to maintain their loyalty. For Low CLV customers, we need to explore strategies to enhance their purchase frequency or spend.

# %%
# Calculate average CLV of each segment
avg_clv_segment = clv_df.groupby('CLV_Segment')['CLV'].mean()

# Convert the series to a DataFrame and reset the index
avg_clv_df = avg_clv_segment.reset_index()

# Rename the columns for clarity
avg_clv_df.columns = ['CLV_Segment', 'Average_CLV']

# %%
# Print the DataFrame
print(avg_clv_df)
# Out:
#   CLV_Segment  Average_CLV
# 0         Low   180.271657
# 1      Medium   782.260473
# 2        High  8869.251070

# %%
# Plot
fig, ax = plt.subplots(figsize=(8,6))
sns.barplot(x=avg_clv_segment.index, y=avg_clv_segment.values, palette="Blues_d")
plt.title('Average CLV by Segment')
plt.xlabel('CLV Segments')
plt.ylabel('Average CLV')

# Format y-axis as dollars
fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick)

# Set y-ticks
min_val = 0  # start at $0
max_val = int(avg_clv_segment.max()) + 500  # go a bit over the max value
ax.set_yticks(np.arange(min_val, max_val, step=500))  # Set the step size to $500

# Save figure to file in the Downloads folder
save_path = os.path.join(os.path.expanduser('~'), 'Downloads', 'Average CLV by Segment.png')
plt.savefig(save_path, bbox_inches='tight', dpi=300)

plt.show()

# %% [markdown]
# Customers in the Low CLV segment contribute an average of approximately $180 to our revenue over their expected lifetime. These customers may be occasional shoppers or those who spend less per transaction. They represent a potential area for growth, as strategies to increase their purchase frequency or transaction size could significantly impact our total revenue.
#
# The Medium CLV segment comprises customers who, on average, contribute about $782 over their expected lifetime. These customers provide a reliable source of income and may be regular shoppers or those who spend a moderate amount per transaction. Strategies like cross-selling and upselling might be effective to enhance their contribution to the business.
#
# The customers in the High CLV segment are the most valuable to our business. With an average CLV of approximately $8,869, these customers likely make frequent purchases or spend substantial amounts per transaction. They are crucial to our business's overall revenue and profitability. Retention strategies, such as loyalty programs and personalized marketing, could be instrumental in maintaining their high level of engagement and ensuring their continued patronage.
#
# In conclusion, understanding these segments can help us refine our marketing and customer engagement strategies to maximize the overall Customer Lifetime Value.

# %% [markdown]
# <a id="MBA"></a>
# ## Market Basket Analysis MBA

# %% [markdown]
# #### Market basket analysis is a type of analysis often used in retail to understand the purchase behavior of customers. It's based on the concept that if you buy a certain group of items, you are more (or less) likely to buy another group of items.

# %%
# Reload the Data
data = pd.read_csv('Downloads/online_retail.csv')
data.head()

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# When preforming a Market Basket Analysis it's common practice to strip extra space from `Description`, as well as standardizing text to lower case and remove special characters.

# %%
# Stripping extra spaces from the description
data['Description'] = data['Description'].str.strip()
  
# Convert to lower case
data['Description'] = data['Description'].str.lower()

#Remove special characters
data['Description'] = data['Description'].str.replace('[^\w\s]', '')

# %%
# drop rows with negative values in Quantity and UnitPrice columns
data = data.drop(data[data['Quantity'] < 0].index)
data = data.drop(data[data['UnitPrice'] < 1].index)
# We're going to remove any item priced less than $1 ($0-$.99 removed)

# %%
# drop all rows that contain missing values
data.dropna(inplace=True)

# %%
# Filter out rows containing 'postage' or 'dotcom postage' in the description
data = data[~data['Description'].str.contains('POSTAGE|DOTCOM POSTAGE', case=False)]

# %% [markdown]
# ### We'll only EIRE sales
#
# I wanted to use UK sales, but the data is too big to process on my machine.

# %%
basket_EIRE = (data[data['Country'] =="EIRE"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
# Show a subset of columns
print(basket_EIRE.head())

# %% [markdown]
# We now need to consolidate the items into 1 transaction per row with each product 1 hot encoded.

# %% [markdown]
# ### One-Hot encode our dataset

# %% [markdown]
# One-hot encoding is a process of converting categorical data to a format that could be provided to machine learning algorithms to improve predictions. With one-hot, we convert each categorical value into a new categorical column and assign a binary value of 1 or 0. Each integer value is represented as a binary vector. All the values are zero, and the index is marked with a 1.

# %%
# Any positive quantity is converted to 1 and anything less than 0 is set to 0.
def hot_encode(x): 
    if(x<= 0): 
        return 0
    if(x>= 1): 
        return 1

basket_encoded = basket_EIRE.applymap(hot_encode) 
basket_EIRE = basket_encoded

# %% [markdown]
# ### Bulding the models and analyzing the results

# %%
# Building the model
frq_items = apriori(basket_EIRE, min_support = 0.05, use_colnames = True)

# %%
# Collecting the rules in a dataframe
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])

# %%
print(rules.head())

# %% [markdown]
# Above is a list of rules with corresponding support, confidence and lift for each rule. The rules are sorted by decreasing confidence and lift.
#
# These rules can then be used to make predictions about future customer behavior and can inform strategies for up-selling, cross-selling, or even stock reordering. For instance, if we find a rule that suggests customers often buy "White Hanging Heart T-Light Holder" and "White Metal Lantern" together, we might want to place these items close together in the store or bundle them in promotions.

# %%
# Exporting the results to a CSV file
filename = 'market_basket_analysis_results.csv'

# Create the path
save_path = os.path.join(os.path.expanduser('~'), 'Downloads', filename)

# Save the results to a CSV file
rules.to_csv(save_path, index=False)

# %% [markdown]
# I exported the results to a CSV as this information can be very useful for the web development team, who can leverage these insights to implement features on a website that enhance cross-selling and upselling.

# %%
# Let's see what the file looks like
MBA = pd.read_csv('Downloads/market_basket_analysis_results.csv')
MBA.head(20)

# %% [markdown]
# ### Here are the explanations for each column:
#
# #### Antecedents:
# - These are the items that a customer has already put in their "basket". For example, if a customer has selected the 'GREEN REGENCY TEACUP AND SAUCER', 'REGENCY SUGAR BOWL GREEN', etc., these items are the antecedents.
#
# #### Consequents:
# - These are the items that the customer is likely to add to their "basket". For instance, if the antecedents include 'GREEN REGENCY TEACUP AND SAUCER', the consequent might be 'ROSES REGENCY TEACUP AND SAUCER'. This means that customers who buy the 'GREEN REGENCY TEACUP AND SAUCER' are likely to also buy the 'ROSES REGENCY TEACUP AND SAUCER'.
#
# #### Antecedent support:
# - This is the proportion of transactions that include the antecedent item(s). For example, a 0.069444 antecedent support for 'GREEN REGENCY TEACUP AND SAUCER' means that about 6.94% of all transactions included this item.
#
# #### Consequent support:
# - Similar to antecedent support, this is the proportion of transactions that include the consequent item(s).
#
# #### Support:
# - This is the proportion of transactions that include both the antecedent and the consequent. A high support means that the antecedent and consequent occur together more frequently.
#
# #### Confidence:
# - This is the probability that a transaction includes the consequent, given that it includes the antecedent. A confidence of 1 means that every time the antecedent items are bought, the consequent is also bought.
#
# #### Lift:
# - This measures how much more likely the consequent is purchased when the antecedent is purchased, while controlling for how popular the consequent is. A lift greater than 1 indicates that the antecedent and consequent are more likely to be bought together than would be expected if they were independently purchased.
#
# #### Leverage:
# - This measures the difference between the observed frequency of the antecedent and the consequent appearing together and what would be expected if they were independent. An itemset has a leverage of 0 indicates independence.
#
# #### Conviction:
# - This is a measure of the dependency of the consequent on the antecedent. A high conviction means that the consequent is highly depending on the antecedent. For instance, if the conviction is 'inf', it means the consequent is always purchased when the antecedents are purchased.
#
# #### Zhang's Metric:
# - This is another measure of the rule interestingness that captures both the direction and the strength of the rule. It ranges from -1 to +1, with +1 indicating a strong positive association between the antecedent and consequent, -1 a strong negative association, and 0 no association.
#
# #### Using this table, we can design strategies to increase sales. For example, we can use these rules for cross-selling, up-selling, and for personalized advertising.

# %% [markdown]
# ----

# %% [markdown]
# <a id="Conclusion"></a>
# ## Conclusion

# %% [markdown]
# This project successfully analyzed key retail metrics to drive online retail strategy. My insights identified top-selling products and high-value customers, enabling targeted marketing and retention strategies. This, coupled with dynamic pricing and inventory management strategies, is expected to optimize profitability and revenue.
#
# However, our Customer Lifetime Value analysis was a simplified version without profit margins, due to lack of product cost data; future datasets should include this for enhanced precision.
#
# Geographic and time-based analyses informed logistics and promotional strategies, while our RFM and cost-volume-profit analysis further provided insights into customer behavior.
#
# In summary, this project has laid a strong foundation for data-driven decision making, aiming to increase revenue, customer loyalty, and optimized inventory management. The derived insights will serve as a guide for refining the retail strategy and future growth.
